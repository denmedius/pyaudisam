# %% [markdown]
# <!-- Auto table of contents -->
# <h1 class='tocIgnore'>Générateur semi-automatique de page HTML "quizz oiseaux"</h1>
# <p>(application des "Oiseaux à l'Oreille" : les quizz <b>2019</b>)</p>
# <div style="overflow-y: auto">
#   <h2 class='tocIgnore'>Table des matières</h2>
#   <div id="toc"></div>
# </div>

# %%
# %%javascript
# $.getScript('../../ipython_notebook_toc.js')

# %% [markdown]
# # Imports

# %%
import os
import datetime as dt

from collections import OrderedDict as odict

import requests

from IPython.display import HTML

# %%
import sys
sys.path.append('..')

import quizz

import importlib as implib

# %%
# Les étapes : les mêmes pour tous les quizz et tous les exercices.
KEtapes = \
[quizz.DescripteurEtape(index=1, id='lancement', titre='Les enregistrements à analyser et les 1er indices'),
 quizz.DescripteurEtape(index=2, id='indices2', titre='Quelques indices à mi-parcours'),
 quizz.DescripteurEtape(index=3, id='reponse', titre='Les réponses : analyse détaillée des enregistrements')]

# %% [markdown]
# # Commutateur de publication locale ou internet

# %%
KDossierQuizz = '.'

pubLocale = True

dossierSons = os.path.join(KDossierQuizz, 'enregistrements')

if pubLocale:
    
    # 1) Locale
    urlDossierSons = dossierSons.replace('\\', '/') # Jouer les sons en lisant les fichiers locaux.
    urlDossierAnnexes = os.path.join(KDossierQuizz, 'fichiers').replace('\\', '/') # idem, ailleurs

else:
    
    # 2) Internet
    urlDossierSons = '.' # Jouer depuis XenoCanto si enregistrement en vient, et n'a pas eté modifié ('-extrait'),
                         # sinon depuis le dossier de la page HTML
    urlDossierAnnexes = '.' # Fichiers annexes sur mon site, dans le dossier de la page HTML

# %% [markdown]
# # Préambule et remerciements

# %%
# texte syntaxe markdown
KPreambule = \
"""
L'automne 2019 approche, et les quizz d'ornithoreille recommencent !

Exactement sur le même modèle que les années précédentes, alors si vous connaissez déjà,
vous pouvez vous épargner le blabla qui suit, et passer directement au <a href="#Aout">quiz d'août</a> :-)

Chacun de ces exercices, nommé comme le mois de 2019 durant lequel il a été lancé, se déroule en *3 étapes*,
publiée chacune 3 semaines après la précédente :
1. la première, le **lancement**, vous donne accès aux enregistrements à analyser
   et à quelques premiers indices pour démarrer,
2. la deuxième, à **mi-parcours**, vous donne des indices plus conséquents, pour confirmer ou pas vos premières idées
   et / ou pour aller plus loin en ciblant quelques séquences plus difficiles,
3. la troisième et dernière, pour terminer, vous donne la "**solution**", en détaillant pour chaque enregistrement
   et chaque espèce, les différents types de chants et cris entendus, et les instants précis concernés.

Pour accéder à l'étape suivante, lorsqu'elle est publiée, il vous suffit de cliquer sur le **petit oeil vert**
<img height="16" src="{{dossierAttache}}/fa-eye-regular.svg" alt="Montrer"/>
situé sous le titre de cette dernière ; bien sûr, tant qu'elle n'est pas publiée, vous ne verrez rien de plus ;-)

Chaque quiz porte sur **plusieurs enregistrements** (en général 3) indépendants, pour varier les milieux et les espèces.

Pour chaque enregistrement (répété à chaque étape), vous trouverez :
* un **lecteur audio intégré**, pour l'écouter, le ré-écouter ... etc, autant de fois que nécessaire,
* un **lien de téléchargement**, pour pouvoir l'analyser tranquillement et précisément
sur votre tablette ou ordinateur, avec un lecteur plus pratique notamment en ce qui concerne
le positionnement temporel ; pour télécharger l'enregistrement, il vous suffit de cliquer sur le bouton
<img height="16" src="{{dossierAttache}}/fa-download-solid.svg" alt="Télécharger"/>
(à moins qu'il ne faille un clic droit, suivi de "enregistrer la cible du / le lien sous ..."),
* le nom de l'**auteur** de l'enregistrement et les détails de sa **licence** de publication,
* à la dernière étape, si disponible, le lien vers la **page du site source** de l'enregistrement
  (xeno-canto.org en général).

Pub. <a href="http://audacity.fr/" target="_blank">Audacity</a> est - entre autres - un lecteur audio très pratique
et précis pour la gestion du temps : essayez-le, je vous le conseille :-) ; il est disponible gratuitement
et en toute sécurité (logiciel Open Source) sous Windows, Mac OS ou Linux (mais pas Android ou i-OS :-(.

Chaque quiz permet à chacun de jouer **quel que soit son niveau**, du débutant au plus expérimenté :
si vous ne trouvez pas tout de A à Z, c'est **normal**, certains enregistrements sont plus difficiles
que d'autres, et à dessein : à vous, pour chaque concert, de trouver **votre défi personnel** ;
par exemple, au delà des espèces que vous avez reconnues rapidement, en choississant 1 chant (ou un cri), ou 2,
que vous ne reconnaissez pas, mais pour lequel les indices à mi-parcours vous orientent suffisamment,
et en cherchant vous-même la solution ailleurs (les <a href="http://jpmeuret.free.fr/nature.html" target="_blank">
supports de formation</a>, bien sûr, mais aussi des CD, des applis dédiées, des livres, des sites internet
comme <a href="http://www.oiseaux.net/oiseaux/france.html" target="_blank">oiseaux.net</a>,
<a href="https://www.xeno-canto.org/" target="_blank">xeno-canto.org</a>, des amis, et surtout les oiseaux réels
lors de vos ballades, dans votre jardin ...).

Ce défi personnel, que vous seul(e) pouvez ajuster à vos connaissances actuelles, vous permettra
de progresser, en vous poussant **au delà de ce que vous savez** déjà ; mais il ne devra pas être **trop ambitieux**
d'un coup, car l'important, c'est d'éviter de dépasser le niveau de frustration qui fait renoncer,
et de rester dans celui qui pousse à avancer :-)

Et puis gardez confiance : l'exercice "en intérieur" sur ordinateur n'est pas simple, tout le monde le dit :
* on n'est pas immergé dans le milieu naturel,
* la qualité du son n'est pas toujours très bonne (enregistrement, casque, haut-parleurs, ...),
* on ne peut pas tourner la tête pour mieux entendre ... même en stéréo, on manque de repères dans l'espace,
* ...

Vous constaterez vite, lors de vos ballades "dans le monde réel", avec les espèces que vous connaissez,
que vous êtes plus à l'aise à l'extérieur : meilleur son, moins de bruit de fond, plus de clarté,
plus de profondeur, ... c'est normal, aucun intermédiaire entre les oiseaux et vos oreilles !

... Mais il y a un hic : en nature, il n'y a pas de bouton "Rejouer" ;-)

Dernier détail, mais d'importance, je compte sur vous pour me les signaler les **coquilles** et **erreurs**
qui se sont inévitablement glissées dans ce qui suit, à me faire part de votre **désaccord** éventuel
sur telle ou telle affirmation ou identification, ou encore à me signaler toute chose que j'aurais "**zappée**"
dans les enregistrements :-)

Amusez-vous bien !
"""

# %%
KAttribsEtMercis = \
"""
Merci aussi à Annie, Camille, Dominique, Florence, Monique et Sylvain pour leurs questions et remarques
bien utiles pour affiner les indices de mi-parcours et les listes de confusions possibles, et pour leurs trouvailles
qui m'ont permis de creuser d'avantage les analyses et de compléter ainsi les listes d'espèces avec celles
que j'avais zappées :-)

Merci aussi à <a href="https://www.faune-auvergne.org/index.php?m_id=7&frmAuthor=69" target="_blank">
Jean-Claude Lablanquie</a> et <a href="https://www.faune-auvergne.org/index.php?m_id=7&frmAuthor=32" target="_blank">
Romain Riols</a> pour leurs splendides photos de Rouge-queue à front blanc et de Bruant jaune en haut de page
(tous droits réservés).
"""

# %% [markdown]
# # Quizz d'août

# %%
KAoutIntro = """
  Trois concerts relativement aérés pour recommencer doucement l'entraînement, dans des milieux variés,
  de notre moyenne montagne auvergnate aux abords de la Méditerranée vers Montpellier ...
"""

# %%
KAoutStGenesChampEstive = quizz.DescripteurExercice(

  index='a',
  id='StGenesChampEstive',
  titre="Estive à Saint-Genès-Champanelle",
  lieu="La Croix Parla, Saint-Genès-Champanelle, Puy-de-Dôme", altitude=970,
  date="7 juillet 2019", heure="à l'heure du pique-nique", duree="54 s",
  auteur="<a href=\"http://jpmeuret.free.fr/nature.html\" target=\"_blank\">Jean-Philippe Meuret</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-sa/4.0/deed.fr\" target=\"_blank\">CC BY-NC-SA</a>",
  milieux="""Estive, haies, lande en lisière de pinède claire, saulaie humide au loin ... en moyenne montagne.""",
  fichierSon="190707-1301-StGenesChampanelleCroixParla-Concert-JPM-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
    
  etapes=dict(
      
    lancement="""
      Un petit concert de début d'été plutôt aéré, et pas uniquement par le vent, avec :
      
      * 5 espèces à plumes : des passereaux bien différents (assez à très communs),
      
      * 1 espèce à laine (mais qui se sert d'un instrument pour se faire remarquer !),
      
      * et 1 criquet (l'été, 'faut bien s'occuper ... si ça vous dit ;-).
      
      Désolé, le nécessaire nettoyage de l'enregistrement l'a rendu plus clair, mais moins réaliste ... 
      """,
          
    indices2="""
      Au premier plan, un passereau campagnard spécialiste du chant en vol (mais non exclusif pour autant)
      avec ses enchaînements de trilles variées ; par ex. à 0.5s, 9.5s, 16.5s ...
      
      Pas très loin non plus, une autre espèce de nos campagnes qui chante beaucoup en vol aussi,
      mais moins dans les aigus, plus dans la douceur à l'oreille (sa "rondeur" à tous points de vue) ;
      d'abord de manière moins habituelle à 7.5-10s et 12.5-16s (tuî tuî ...), puis plus classiquement,
      à 19-22s, 26-27s, ... etc. 
      
      Moins facilement audible, encore un campagnard, mais préférant des milieux plus frais :
      * un individu émet une seule phrase, classique et complète, à 36.5-39s ; mais il est loin,
        il y a du vent : le début n'est pas facile à entendre (la fin devrait cependant allumer
        un voyant vert dans votre cerveau :-),
      * un autre individu émet 2 phrases étonnamment aiguës, et sans leur fin "attendue",
        à 5.5s, 26.5s et 51.5s (eh oui, c'est la même espèce) ;
        pour l'anecdote, ce sont ces phrases bizarres qui m'ont fait dégainer mon enregistreur,
        alors que mon estomac avait une autre priorité à cette heure, après une matinée de ballade
        dans une vieille forêt proche (forêt donc vous ré-entendrez parler par ailleurs ;-).
        
      A l'arrière plan, une espèce très commune partout fait entendre une unique phrase, à 35.5s.
      
      A l'arrière plan aussi (à au moins 200m, de mémoire), une espèce des milieux frais
      aux longues phrases rapides, bien articulées, beaucoup dans les graves (pour un passereau de cette taille)
      se fait entendre "par vagues" (sans doute le vent variable) tout au long de l'enregistrement,
      et plus clairement à 3-6s, 11-13s et 46s.
      
      Et il y a aussi peut-être un autre chanteur, d'une espèce très voisine et vaguement concurrente :
      on entend des bribes assez caractéristiques de ses fins de phrases à 6.5-7s et 46-47s,
      avec une impression de distance moins grande peut-être ; mais ... comme à chaque fois,
      c'est dans le courant d'une phrase de l'espèce précédente, dont certains individus sont imitateurs ...
      il y a un doute, qui ne sera pas levé : 50 / 50 :-(
      
      Quant au criquet, il n'est pas très difficile à trouver en bas de page sur
      <a href="http://chant-orthoptere.com/" target="_blank">http://chant-orthoptere.com/</a>
      (et soyez patient(e)s, écoutez les enregistrements jusqu'au bout, ils montrent probablement
      très bien la variété des stridulations de certaines espèces, dont celle qui nous intéresse ici).
      """,
          
    reponse="""
      Au premier plan donc, un <b>pipit des arbres</b> enchaîne ses phrases assez véhémentes composées
      de 2 à 4 trilles ou répétitions de notes plutôt "rudes" et pas très tonales, un peu rêches même :
      * 2 trilles différentes s'enchaînent entre 1 et 3.5s,
      * ça recommence avec les 2 mêmes entre 9.5s et 11.5s,
      * idem entre 16.5 et 18.5s (cette fois cependant, la 2nde trille est plus courte),
      * idem entre 24.3 et 26.2s (même 2nde trille raccourcie),
      * ça recommence entre 32 et 34.5s, mais cette fois, une 3ème trille plus rapide, plus sèche
        et descendante suit : c'est celle qui se prolonge jusqu'au perchoir lorsque l'oiseau
        descend en vol "parachute" ... mais ici elle est assez courte ... car le chanteur est
        très probablement perché (toutes ses phrases sont raccourcies ou tronquées)
      * le schéma initial à 2 trilles reprend entre 43 et 45s,
      * enfin la dernière phrase est similaire, mais commence par une 4ème trille très similaire
        à la seconde (à notes plus courtes ?).
      
      Au second plan, plutôt en alternance avec le pipit, les répétitions de notes plus douces,
      plus rondes, plus graves, nettement plus tonales ... d'une <b>alouette lulu</b>, mais avec des "phrases"
      plutôt décousues, comme composées chacune d'une seule trille, alors qu'habituellement,
      c'est plutôt un enchaînement de plusieurs différentes :
      * sa première phrase commence en douceur à 7.5s, s'amplifie ... tuî tuî ... 
        puis se trouve masquée par le 2nde phrase du pipit à partir de 9.5s,
      * sa 2nde phrase (même note répétée, légèrement descendante) est audible en entier,
        entre 12.5 et 16.5s, le doux début à peine brouillé par une lointaine fauvette des jardins
        (voir ci-dessous),
      * sa 3ème phrase est différente, entre 19 et 22s : une série nettement descendante
        et assez rapide de doux "liu", un peu tristes ou mélancoliques ; en fait, c'est la 2nde partie
        de certaines phrases complètes assez fréquentes ... mais ici, la pause est tellement longue
        (attendait-elle que le pipit finisse ?) qu'on a du mal à relier ces 2 parties,
      * sa 4ème phrase, très similaire (mais ou est la 1ère partie normale cette fois ?),
        entre 24s et 27s, est "traversée" par la 4ème phrase du pipit,
        mais maintenant que vous avez les "liu" en mémoire, vous la tenez quand même :-)
      * entre 30 et 32.5s, sa 5ème phrase (la même) se termine juste avant la 5ème du pipit,
      * une 6ème phrase écourtée, tronquée, ou partiellement masquée par le vent (?)
        et la 6ème phrase du pipit (ça c'est sûr), entre 43 et 44s,
      * enfin, entre 47.5 et 50s, une série plate et assez rapide de "du" ou "diu" (très petit i),
        qui m'a donné du fil à retordre (et je ne suis pas le seul), faisant penser à un verdier ;
        mais c'est bien la même hauteur, la même douceur, la même rondeur, et enfin le même timbre
        mélancolique de la lulu ... je vote pour elle sans état d'âme :-)
      
      Au second plan aussi, la raison initiale de cet enregistrement qui s'est révélé plus riche que prévu
      (pour votre plus grand bonheur ... ou malheur ;-?), une trille très rapide d'environ 2s, à 5.5s,
      26.5s et 51.5s, émise par un <b>bruant jaune</b> chantant vraiment haut dans les aigus
      (8 kHz au lieu des 5-6 kHz habituels), et sans la longue note finale plus basse qui nous sauve si souvent.
      
      Remarquez que la dernière de ces trilles sur-aiguës se déroule en même temps que la dernière phrase du pipit,
      mais que vous n'avez pas trop de mal à l'entendre quand même : c'est que les 2 sons ont un volume
      suffisant (ça aide bien sûr), mais surtout des bandes de fréquences bien disjointes !
      
      Remarquez aussi le 2nd bruant jaune, au second plan également, entre 37 et 39s, qui lui chante
      dans les règles officielles, à la "bonne" hauteur, et avec la longue note finale plus grave,
      on lui dit merci ! Pour quoi un second ? En fait, ça ne s'entend pas, ils sont à même "distance
      sonore", c'est juste qu'à l'oreille, sur place, j'ai pu constater qu'ils n'étaient pas au même endroit :-)
        
      A l'arrière plan, à 35.5s, un <b>merle noir</b> chante (1 seule phrase).
      
      A l'arrière plan aussi (à au moins 200m, de mémoire), une <b>fauvette des jardins</b> débite avec virtuosité
      ses longues phrases liquides et graves, parfaitement rytmmées, aux notes bien séparées malgré la vitesse ;
      à cause du vent, le volume est changeant, on entend comme des "vagues", avec des moments plus "clairs"
      à 3-7s et 11-13s, et plus "flous" à 28-29s, 45-46s, 52-53s.
      
      Enfin, et cela restera hypothétique pour moi, mais il y peut-être une fauvette à tête noire aussi :
      on entend des bribes plus ou moins caractéristiques de ses flutés finaux à 6.5-7s, 22.5-23.5s,
      40.5-51.5s, 46-47s ; mais ... comme à chaque fois, c'est plus ou moins dans le courant d'une phrase
      de la fauvette des jardins, dont certains individus sont imitateurs, et que le vent n'aide pas à clarifier
      les choses ... il reste un gros doute !
      
      Quant au criquet, pour les amateurs, c'est le <b>Criquet jacasseur / Staurodère scalaire</b>
      (<i>Chortippus / Stauroderus scalaris</i>), l'avant dernier en bas de cette page
      <a href="http://chant-orthoptere.com/" target="_blank">http://chant-orthoptere.com/</a>
      (le 3ème tiers de l'enregistrement correspond très bien, le 1er tiers assez bien aussi),
      assez commun dans les prairies à partir des moyennes altitudes ; sa stridulation est double,
      avec 2 timbres bien distincts émis en même temps sur des rythmes différents : c'est probablement
      le même phénomène que chez le Criquet des jachères / (<i>Chortippus molis molis</i>),
      chaque couple fémur - tegmen (élytre), le gauche et le droit, étant "chargé" indépendamment
      d'un des 2 sons / rythmes !
      """))

HTML(KAoutStGenesChampEstive.lecteurHtml(urlDossierSons))

# %%
KAoutClairiereBassesCombrailles = quizz.DescripteurExercice(

  index='b',
  id='PatureBoisBassesCombrailles',
  titre="Clairière en fond de vallon, dans les Basses Combrailles",
  lieu="Le Boudelet (est), Champs, Puy-de-Dôme", altitude=440,
  date="21 avril 2019", heure="8h30 du matin", duree="57 s",
  auteur="<a href=\"http://jpmeuret.free.fr/nature.html\" target=\"_blank\">Jean-Philippe Meuret</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-sa/4.0/deed.fr\" target=\"_blank\">CC BY-NC-SA</a>",
  milieux="""Bocage, bois, prairies, landes en Basses Combrailles""",
  fichierSon="190421-0831-ChampsBoudeletE-Concert-JPM-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
    
  etapes=dict(
      
    lancement="""
      Un autre concert pas trop "chargé", en plein printemps cette fois, avec un bel écho de lisière proche,
      pour une ambiance et des espèces très communes et plutôt forestières (au moins 11).
      """,
          
    indices2="""
      Au premier plan, 2 espèces de passereaux assez éloignées par les moeurs et l'aspect :
      
      * la 1ère, un insectivore plutôt terrestre, occupe une bonne partie de l'espace et du temps
        de l'enregistrement, avec son chant à longues notes oscillantes très modulées
        (débuts de phrases à 1s, 1.7s, 12.5s, ... etc),
        
      * la 2nde, très arboricole, égrène avec constance ses séries de "uîi" sonores et traînants
        (débuts de phrases à 0s, 7.3s, 15s) ; attention, l'espèce émet couramment d'autres beaux motifs,
        mais toujours en séries, plus ou moins rapides.
        
      A l'arrière plan, dans les graves :
      
      * entre 1.5s et 12s au moins (il s'éloigne), un oiseau plus difficile à voir qu'à entendre
        dans nos campagnes, avec son chant simple à 2 tons répétés à longueur de journée,
        
      * plus loin, très loin, un grand passereau qui mériterais plus d'admiration (pour son intelligence,
        pas pour sa voix ... quoiqu'elle soit énormément "plastique"), à 5-7s et 16-19s au moins,
        
      * assez loin aussi, mais plus repérable par la plus grande longueur des éléments de son chant simple,
        un non-passereau très commun dans nos bois, parc urbains et bocages, à 28-35s,
        
      * un peu moins grave (question de taille forcément, quoique ...), entre 53 et 56s,
        une répétitition flûtée dont le volume monte et descend bizarrement, peut-être l'effet du vent,
        mais c'est assez clair, descendant (en fréquence) ; on l'entend aussi moins bien à 43-45s
        (même effet de volume changeant), et cette fois la série ne descend pas vraiment,
        ce qui fait penser à une autre espèce proche (quoique plus grande) ...
        mais le timbre est tellement identique à 53-56s que je dirais que c'est la même espèce.
      
      A l'arrière plan, dans les aigus :
      
      * un chant simple de petites notes aiguës, assez net vers 6-7s, moins à 12s, trop loin,
      
      * à 51s, une fin de phrase typique d'une espèce vraiment très commune et peu discrète
        (surtout par la voix), avec un joli écho : la bête est en lisière, ou pas loin,
      
      Et pour finir, en revenant au second plan (ou au 1er et demi ?), toujours dans les aigus, pas facile :
      
      * une mésange, mais laquelle ?
          * à 0s, 9s, 15s, 22.5s, 32s au moins, des phrases de chant assez habituelles,
            mais pas toutes très audibles (brouillées par d'autres chants superposés),
          * à 19s, 21-22s, 24.5-27s, des cris sur-aigus vibrés / roulés de parade d'un couple,
          * à 50-51s, une série descendante de cris très habituels aussi,
      
      * à 10-11.5s et 22-23s au moins, la phrase stéréotypée typique d'une autre espèce
        typiquement forestière,
      
      * à 53s, 4 "cris" fins, délicats, sur un rythme typique un peu hésitant ... très probablement
        un début de phrase de chant d'un joli petit sylvidé forestier (là c'est dur, c'est vrai) ;
        et si ces 4 cris vous font penser à l'inquiétude d'un turdidé bien commun, vous avez bien raison,
        le rythme est étonnamment similaire ... mais non, je ne crois pas, ça manque de puissance :-)
        
      Le compte est bon, 11 :-)
        
      Et puis d'autres choses que je n'identifie pas :
      
      * à 27.5s, ça ressemble à un cri d'une autre mésange, mais sur ce point STOC EPS, je n'en ai jamais
        entendu ; j'ai bêtement coupé l'enregistrement à cet endroit pour supprimer une partie
        très bruitée par le vent, et jeté l'original (c'est malin), du coup, pas moyen de retrouver
        ce qu'il y avait juste avant ; mais ça pourrait être une note du rouge-gorge tout simplement ...
        
      * à 17.4-17.6s, il y a 2 "gouê", le 2nd plus net ... à quoi vous font-ils penser ?
      
      * ... etc.
      """,
          
    reponse="""
      Au premier plan, bien audibles :
      
      * un <b>rouge-gorge familier</b>, occupe une bonne partie de l'espace et du temps de l'enregistrement,
        avec ses longues notes oscillantes très modulées (débuts de phrases à 1s, 1.7s, 12.5s, ... etc),
        
      * une <b>sittelle torchepot</b>, égrène calmement, mais avec constance, ses séries de beaux "uîi" sonores
        et traînants (débuts de phrases à 0s, 7.3s, 15s) ; attention, l'espèce émet couramment d'autres
        jolis motifs, mais toujours en séries, à rythme plus ou moins rapide.
        
      A l'arrière plan, dans les graves :
      
      * un <b>coucou gris</b>, entre 1.5 et 12s, et à 35-36s aussi,
        
      * très loin, une <b>corneille</b> (noire très probablement ;-), envoie quelques kroâaaa traînants,
        à 5-7s et 16-19s au moins,
        
      * assez loin aussi, mais plus repérable, un <b>pigeon ramier</b>, à 28-35s,
        
      * assez net aussi entre 53 et 56s, la longue phrase descendante et flutée d'un <b>pic vert</b> ;
        à 43-45s, qqch de similaire, mais le volume est changeant (à cause du vent probablement),
        et cette fois la série est plutôt plate et fait donc penser à un pic noir ...
        le timbre est cependant très similaire à celui de 53-56s :
        je vote donc pour le même pic vert, avec un doute quand même (le Noir fréquence aussi les lieux :-).
      
      A l'arrière plan, dans les aigus :
      
      * vraiment pas facile (volume faible), un <b>pouillot véloce</b> égrène ses petites notes aiguës,
        assez net vers 6-7s, moins à 12s, trop loin,
      
      * à 51-53s, un beau flûté final de <b>fauvette à tête noire</b>, avec un joli écho de lisière,
      
      Et pour finir, en revenant au second plan (ou au 1er et demi ?), toujours dans les aigus, pas facile :
      
      * une <b>mésange bleue</b> chante ses phrases classiques "tsi dé dé dé ..." à 0s, 9s, 15s, 22.5s, 32s, 38s ;
        la même ou une autre crie aussi à 19s, 21-22s, 24.5-27s : des cris sur-aigus (10-12 kHz)
        vibrés / roulés de parade d'un couple ; quelques cris très habituels aussi à 50-51s,
      
      * à 10-11.5s et 22-23s au moins, un <b>grimpereau des jardins</b> chante sa petite mélodie,
        un peu toujours la même (ex: "ti-ti-tû-i-ti"),
      
      * à 53s, 4 "cris" fins, délicats, sur un rythme typique un peu hésitant ... probablement
        le début d'une phrase interrompue du chant d'un <b>pouillot siffleur</b> ; la "preuve" dans
        <a href="https://www.xeno-canto.org/479467" target="_blank">cet enregistrement de Jack Berteau</a>.
        
        Et si ces 4 cris vous font penser aux cris d'inquiétude d'un merle noir, vous avez bien raison,
        le rythme est étonnamment similaire à certains cas (mais c'est vraiment trop délicat, et la puissance
        attendue n'est pas là ... exemple dans
        <a href="https://www.xeno-canto.org/312424" target="_blank">cet enregistrement de Cédric Mroczko</a>).
        
        Et puis ... une sitelle torchepot n'est pas exclue non plus, ou une même mésange ... un doute subsiste.
        
      Le compte est bon, 11 :-) (quoique ... si le pouillot est en fait une sitelle ou une mésange bleue ...)
        
      Et puis d'autres choses que je n'identifie pas :
      
      * à 27.5s, on dirait un cri de mésange noire, mais c'est une espèce inconnue à cet endroit pour moi
        (STOC EPS depuis 2002) ; peut-être tout simplement une fin de phrase du rouge-gorge ?
        
      * à 17.4-17.6s, il y a 2 "gouê", le 2nd plus net ... qui me font penser à une bribe de grive musicienne,
        mais en l'absence d'autres indices, le mystère restera entier.
      """))

HTML(KAoutClairiereBassesCombrailles.lecteurHtml(urlDossierSons))

# %%
KAoutMaquisForetOccitannie = quizz.DescripteurExercice(

  index='c',
  id='MaquisForetOccitannie',
  titre="Maquis dans les ruines karstiques de Mourèze",
  lieu="Cirque de Mourèze, Hérault", altitude=280,
  date="8 mai 2017", heure="9 heure du matin", duree="45 s",
  auteur="<a href=\"https://www.xeno-canto.org/contributor/SDPCHKOHRH\" target=\"_blank\">Stanislas Wroza</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-sa/4.0/\" target=\"_blank\">CC BY-NC-SA</a>",
  milieux="""Maquis méditerranéens et forêt de piémont, sur chaos karstique, à distance d'habitations.""",
  fichierSon="20170508-0900-MourezeHerault-ConcertMeridional-XC369638-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
    
  etapes=dict(
      
    lancement="""
      En plein printemps toujours, avec 7 ou 8 espèces présentes :
      * 4 assez à très méridionales (mais 3 présentes en Auvergne, ou disparues récemment),
      * les autres très communes partout en France.
      
      Un bien bel endroit, que ce <a href="http://www.herault-tourisme.com/articles/le-cirque-de-moureze-596-1.html"
      target="_blank">Cirque de Mourèze</a>, mais probablement très touristique, si l'on en juge
      par les <a href="https://www.geoportail.gouv.fr/carte?c=3.3585118744300315,43.621308862653734&z=17&l0=GEOGRAPHICALGRIDSYSTEMS.MAPS.SCAN-EXPRESS.STANDARD::GEOPORTAIL:OGC:WMTS(1)&l1=ORTHOIMAGERY.ORTHOPHOTOS::GEOPORTAIL:OGC:WMTS(1)&permalink=yes"
      target="_blank">photos aériennes</a>, qui montrent un réseau dense et fractal typique des "parcours à moutons" ...
      alors qu'il n'y a plus de bétail depuis longtemps (enfin pas à 4 pattes ;-) !
      """,
          
    indices2="""
      Toujours par ordre (décroissant) de "repérabilité" à l'oreille :
      
      * au premier plan, ce beau chant grave et un peu triste, c'est celui d'une espèce méditérranéenne
        mais qui est peut-être encore présente en Auvergne ?
      
      * plus loin, à l'arrière plan, mais facilement audible, un chant grave, en phrases très simples
        composées le plus souvent de 3 répétitions d'un même cri simple lui-même ...
        une belle espèce bien connue de tous, méridionale aussi, mais bien présente
        en Auvergne, quoiqu'en forte régression depuis au moins 30 ans ...
        avec même un 2nd individu répondant plus loin, par ex. à 3.5s, 16.5s, 25.5s,
        
      * assez loin aussi, mais assez nettement repérables à partir de 40s, des "triplets" de notes graves
        dans le même registre que l'espèce précédente, mais plus ou moins allongées ; une espèce
        très commune partout en France depuis son arrivée par l'Italie il y a environ 70 ans
        (mais qui ne paie jamais son coup pour autant) ...
      
      * moins "facile", assez loin (à quelque hauteur dans le ciel ?), et émettant des cris courts, graves,
        mats et liquides à la fois, tous identiques, par ex. entre 11 et 21s ; plusieurs individus,
        comme souvent, d'une espèce méridionale, mais présente quand même un peu partout en France,
        en effectifs peu importants ; un oiseau aux moeurs très aériennes ...
      
      Ensuite, retour aux aigus et à la vitesse qui brouille :
      
      * les 3 fringilles communs :
      
          * le 1er : son cliquetis habituel avec qq trilles sèches est assez reconnaissable,
                     quand on réussit à l'isoler, par ex. à 12s, 20s, 26s, 34s ...
                     
          * le 2ème : plus grave que les 2 autres, mais difficile, car on ne l'entend que par 1 trille à 24.5s,
                      et par 2 trilles différentes s'enchaînant à 32.5s ; mais toutes caractéristiques de l'espèce,
                      
          * le 3ème : encore plus difficile, car là, on n'a droit qu'à 3 débuts de ses phrases sur-aiguës,
                      à 25s, 30.5s et 39s, ou à 3 petites trilles, de celles qu'on entend habituellement
                      entre les longues phrases, à 6s, 11s et 14.5s.
        
      * et si vous avez le coeur bien accroché ... au second plan, difficile, mais on entend assez nettement
        entre 3 et 7s son chant précipité, sur-excité, mais finalement assez doux à l'oreille,
        malgré quelques accents sur-aigus, peut-être simplement à cause de son faible volume sonore ;
        oui, c'est une fauvette méditéranéenne, mais laquelle ?
        
        eh bien forcément l'une de ces trois-ci : comparez, cherchez les "trucs" qui ressortent et différentient :-)
        <table>
          <tr>
            <td>l'infernale Mélanocéphale</td>
            <td>
              <audio controls>
                <source src="https://www.xeno-canto.org/471826/download" type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              <a href="https://www.xeno-canto.org/471826/download" download>
                <img height="20" src="{{dossierAttache}}/fa-download-solid.svg" alt="Télécharger" />
              </a>
            </td>
            <td>
              par <a href="https://www.xeno-canto.org/contributor/SDPCHKOHRH" target="_blank">Stanislas Wroza</a>
            </td>
            <td>
              licence <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/" target="_blank">CC BY-NC-SA</a>
            </td>
            <td>
              <a href="https://www.xeno-canto.org/471826" target="_blank">Page du site source</a>
            </td>
          </tr>
          <tr>
            <td>la tornade Passerinette</td>
            <td>
              <audio controls>
                <source src="https://www.xeno-canto.org/385183/download" type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              <a href="https://www.xeno-canto.org/385183/download" download>
                <img height="20" src="{{dossierAttache}}/fa-download-solid.svg" alt="Télécharger" />
              </a>
            </td>
            <td>
              par <a href="https://www.xeno-canto.org/contributor/TJSRKPHQNP" target="_blank">Cedric Mroczko</a>
            </td>
            <td>
              licence <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/" target="_blank">CC BY-NC-SA</a>
            </td>
            <td>
              <a href="https://www.xeno-canto.org/385183" target="_blank">Page du site source</a>
            </td>
          </tr>
          <tr>
            <td>la furie Pitchou</td>
            <td>
              <audio controls>
                <source src="https://www.xeno-canto.org/135383/download" type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              <a href="https://www.xeno-canto.org/135383/download" download>
                <img height="20" src="{{dossierAttache}}/fa-download-solid.svg" alt="Télécharger" />
              </a>
            </td>
            <td>
              par <a href="https://www.xeno-canto.org/contributor/UXGZWVYDFE" target="_blank">Fernand Deroussen</a>
            </td>
            <td>
              licence <a href="https://creativecommons.org/licenses/by-nc-nd/3.0/" target="_blank">CC BY-NC-ND</a>
            </td>
            <td>
              <a href="https://www.xeno-canto.org/135383" target="_blank">Page du site source</a>
            </td>
          </tr>
        </table>
        
        pour ne rien vous cacher, je travaille en même temps que vous ici, et je "galère",
        sans savoir encore si je serai sûr de ma réponse =%-]
      """,
          
    reponse="""
      Du plus proche au plus lointain, dans les graves, sans trop de difficulté :
      
      * au 1er plan, une <b>fauvette orphée</b>, avec son beau chant répétitif un peu triste,
        aux notes graves, rauques, vibrées, sur 2 tons "wou-rru ..." ou "wi-rru ..." ;
        à 1s, 7s, 15s, ... etc ;
        
        notez le bel écho "de falaise" de la phrase à 35s, lorsque l'oiseau s'est éloigné ...
        
      * à l'arrière plan, les "houp houp houp" d'une <b>huppe fasciée</b>, 0.5s, 3s, 10s, 12s, ... ;
        
        et même un 2nd individu répondant plus loin, à 3.5s, 16.5s, 25.5s ...
        
      * assez loin aussi, bien net à partir de 40s, le chant d'une <b>tourterelle turque</b>
        (mais, en poussant le volume, déjà audible à 5s, 7s, à partir de 26s),
      
      * à quelque distance (dans le ciel), les "plrup" liquide et roulés, mats, d'un groupe de <b>guêpiers
        d'Europe</b>, par ex. entre 11 et 21s ...
      
      Ensuite, plus difficile, dans les aigus et la vitesse, au second plan :
      
      * les 3 fringilles communs :
      
          * un <b>chardonneret élégant</b> avec ses phrases cliquetantes, à 12-13.5s, 20-21s, 25.5-27s,
            33.5-35s et 36.6-38.5s ... notez la trille courte "trrzt", roulée et sèche à la fois, terminant
            chacune des 3 dernières phrases ... un indice quasi-diagnostique pour cette espèce,
            à chercher dans brouhaha,
            
          * un <b>verdier d'Europe</b> : pas simple, il ne faut pas le rater : 1 trille "tudududu" à 24.2-25s,
            et 2 trilles différentes "tudududu-tziééééé" s'enchaînant à 32.5-34s, toutes bien caractéristiques
            de l'espèce,
                      
          * plus difficile encore, un <b>serin cini</b> commence, sans les continuer, 3 phrases sur-aiguës,
            à 25s, 30.5s et 39s ; il émet aussi 3 petites trilles métalliques et très rapides, diagnostiques,
            à 6s, 11s et 14.5s.
        
      * et enfin, entre 3 et 7s, une fauvette méditéranéenne avec son chant précipité mais assez doux à l'oreille,
        avec quelques notes pures (quoique légèrement "couinantes") et étirées : je penche très fortement
        pour une <b>fauvette passerinette</b>, à 90% ... les 10% restant pour l'hypothèse d'une mélanocéphale au chant
        particulièrement doux, et étonnament dénué des habituels et irrépresssibles trrt trrt trrt de l'espèce ...
        avis plus connaisseurs de ces divas tout à fait bienvenus :-)
      """))

HTML(KAoutMaquisForetOccitannie.lecteurHtml(urlDossierSons))

# %%
KAoutImitations = quizz.DescripteurAnecdote(
  index='a',
  id='Imitations',
  titre="La Fauvette à front blanc",
  auteur="<a href=\"https://www.xeno-canto.org/contributor/OXKHFMOYKQ\" target=\"_blank\">Herman van der Meer</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-nd/2.5/\" target=\"_blank\">CC BY-NC-ND</a>",
  fichierSon="Imitation-HollandeMeridionalePaysBas-XC179508-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
  texte="""
    Une "espèce" assez commune chez nous, en tout cas plus que le Rouge-queue à front blanc lui-même !
    
    Dans cet enregistrement, on entend un vrai rouge-queue à l'arrière plan, à 1s, 7s, 22s, et 51s (sîiii-tru-tru...) :
    commencez par lui :-).
        
    Et la fauvette (à tête noire, bien entendu) au 1er plan, qui imite ce début typique de phrase (sîiii-tru-tru...)
    qui porte si loin quand on y est habitué, sans doute par la puissance de ces 3 ou 4 notes,
    de la longueur de la 1ère (sîiii), et de la répétition des suivantes (tru).
    
    Ici, le passage de l'imitation au chant normal de l'espèce est assez "évident" : pas de "rupture",
    le "fondu-enchaîné" est naturel, le niveau et le timbre sonores sont en continuité parfaite ;
    peu de doute, les notes "rouge-queue" et les notes "fauvette" viennent de la même direction et de la mème distance,
    du même gosier (cela se "sent" même de l'autre côté du "filtre dégradant" que constitue inévitablement
    la chaîne d'enregistrement - restitution, du microphone au haut-parleur ou casque) !
    
    Et puis, profitez-en pour retrouver les autres solistes : un pouillot, un pipit, un troglodyte et un rouge-gorge,
    sans parler de l'autre fauvette à tête noire !
    
    Et pour bien se le mettre dans l'oreille (le Rouge-queue), un autre enregistrement où il est à peu près seul :
    
    <table>
    
      <tr>
        <td>
          <audio controls>
            <source src="https://www.xeno-canto.org/476206/download" type="audio/mpeg" preload="none"/>
          </audio>
        </td>
        <td>
          Rouge-queue à front flanc (Phoenicurus phoenicurus)
        </td>
        <td>
          <a href="https://www.xeno-canto.org/476206/download" download>
            <img height="20" src="{{dossierAttache}}/fa-download-solid.svg" alt="Télécharger" />
          </a>
        </td>
        <td>
          par <a href="https://www.xeno-canto.org/contributor/ILUHRFXDNU" target="_blank">Manuel Grosselet</a>
        </td>
        <td>
          licence <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/" target="_blank">CC BY-NC-SA</a>
        </td>
        <td>
          <a href="https://www.xeno-canto.org/476206" target="_blank">Page du site source</a>
        </td>
      </tr>
      
    </table>
    
    Et pour le plaisir, un autre cas d'imitation par la Fauvette à tête noire toujours
    (d'une espèce qui imite aussi parfois, d'ailleurs ;-), je vous laisse deviner :
    
    <table>
    
      <tr>
        <td>
          <audio controls>
            <source src="https://www.xeno-canto.org/94915/download" type="audio/mpeg" preload="none"/>
          </audio>
        </td>
        <td>
          Fauvette à tête noire (Sylvia atricapilla)
        </td>
        <td>
          <a href="https://www.xeno-canto.org/94915/download" download>
            <img height="20" src="{{dossierAttache}}/fa-download-solid.svg" alt="Télécharger" />
          </a>
        </td>
        <td>
          par <a href="https://www.xeno-canto.org/contributor/FVVKBGKTKP" target="_blank">Gérard Goujon</a>
        </td>
        <td>
          licence <a href="https://creativecommons.org/licenses/by-nc-nd/2.5/" target="_blank">CC BY-NC-ND</a>
        </td>
        <td>
          <a href="https://www.xeno-canto.org/94915" target="_blank">Page du site source</a>
        </td>
      </tr>
      
    </table>
    
    <p style="text-align: right; font-size:70%">(la Grive musicienne, bien sûr :-)</p>

    """)

HTML(KAoutImitations.lecteurHtml(urlDossierSons))

# %% [markdown]
# # Quizz d'octobre

# %%
KOctIntro = """
  Au menu, florilège de chants, cris et tambours (sans trompettes) en forêt de plaine et en montagne ...
  avec 3 concerts qui devraient vous reposer un peu des quizz d'octobre,
  et une espèce "exotique" pour un Auvergnat :-)
  
  N.B. Ne vous acharnez pas trop sur les 1ers indices, ils sont parfois un peu tirés par les ... l'analogie culinaire.
"""

# %%
KOctStDisdierMontagne = quizz.DescripteurExercice(

  index='a',
  id='OctStDisdierHameauMontagne',
  titre="Hameau dans le Dévoluy, Alpes du sud",
  lieu="Saint-Disdier, Dévoluy, Alpes-de-Haute-Provence", altitude=1000,
  date="17 mai 2011", heure="le matin", duree="42 s",
  auteur="<a href=\"https://www.xeno-canto.org/contributor/OOECIWCSWV\" target=\"_blank\">Peter Boesman</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-nd/4.0/\" target=\"_blank\">CC BY-NC-ND</a>",
  milieux="""Hameau en fond de vallée encaissée, dans des prairies de fauche et forêts plus ou moins dégradées
             sur bonnes pentes (moyenne montagne).""",
  fichierSon="110517-hhmm-HameauDevoluy-PBoesman-XC270411-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
    
  etapes=dict(
      
    lancement="""
      En entrée, decrescendo forestier aux 2 turdidés et ses 2 opposés climatiques
      (7 espèces, de justesse, peut-être même 8).
      """,
          
    indices2="""
      Au premier plan, un passereau omni-présent dès qu'il y a des arbres, pratiquement dans tous les milieux,
      qui anime nos paysages sonores de son chant puissant qui porte et raisonne loin.
      
      A la toute fin de l'enregistrement, vous l'avez aussi reconnu, un proche de certains passereaux,
      mais pas génétiquement ; et de cette proximité, les espèces en question s'en passeraient bien ...
      
      En fond sonore, presque tout au long de l'enregistrement, 2 turdidés communs en forêt : est-ce que ça répète,
      est-ce que c'est monocorde, tristounet voire désepéré, est-ce que c'est plus calme, serein, posé ?
      A vous de voir parmis les 3 espèces possibles :-)
      Et si vous avez des doutes, écoutez divers enregistrements de leurs chants
      sur <a href="https://www.xeno-canto.org/" target="_blank">xeno-canto.org</a> !
      
      Au second plan, 2 cousins proches, bien plus haut dans les aigus que les turdidés, aux chants qui portent
      moins loin forcément :
      * la première espèce, très commune, très discrète si l'on ne l'entendait pas quasiment partout au printemps :
        repérez son petit battement sautillant, bien audible à 11-13s et 26-28s,
      * la seconde, plus méridionale, mais présente en Auvergne, s'entend nettement plus souvent que l'autre ici,
        par exemple à 8-9s, 16-17s, ... etc (mais aussi de manière intercalée, un autre individu, plus bas) ;
        c'est une des 2 opposées climatiques.
        
      Enfin, l'autre opposée climatique - probablement peu d'entre vous en connaissent le chant -
      oui, ce sont les grouêch traînant à 20s, 30.5s et 37s, et le cou-clou-lou-lou liquide, hoquetant entre 24.5 et 29s
      (mais il y a d'autres chanteurs plus éloignés semble-t-il) ... cherchez l'espèce parmis celles qui intéressent
      les chasseurs, qui vivent en forêt d'altitude en France (mais plus bas plus au nord), en éliminant les passereaux,
      rapaces, limicoles, canards, ... un oiseau de bonne taille, pas très bon voilier, sociable.
      """,
          
    reponse="""
      Au premier plan, vous l'avez tou(te)s reconnu, c'est bien sûr un **pinson des arbres**, tout prêt du micro ;
      il débite, sans grande variation et à intervalles réguliers, sa phrase dynamique et puissante, bien installé
      sur son poste de chant ! 
      (au loin, on entend aussi un 2nd individu vers 14-15s, une phrase plutôt longue, sur un rythme plus lent
       que la normale, dont la fin - audible difficilement en poussant le volume - semble déformée
       par un autre son parasite).
      
      Les autres chanteurs sont nettement plus éloignés, mais certains sont bien audibles.
      
      Bien sûr, en clôture de l'enregistrement, à 41.7s un seul "cou cou" ... de **coucou gris**, juste à la fin
      de la dernière phrase du pinson (le 1er "cou" n'est pas si facile à capter, mais en ré-écoutant ce passage,
      il devient vite évident).
      
      Evacuons aussi tout de suite le "1er opposé climatique" (nordique), un exotique pour nous-autres auvergnats
      (même si nos montagnes pourraient très bien l'accueillir s'il daignait faire un effort) :
      le "grouêch" traînant à 20s, 30.5s et 37s, le "cou-clou-lou-lou" liquide, hoquetant entre 24.5 et 29s,
      c'est un **tétras lyre** mâle qui chante et parade, probablement sur un "lek"
      ou <a href="https://fr.wikipedia.org/wiki/Aire_de_parade">aire de parade</a> dans un endroit dégagé,
      sous l'oeil attentif d'une ou plusieurs femelles à quelque distance ;
      en forçant le volume entre les phrases du pinson (sinon, ça fait mal, attention à vos précieuses oreilles !),
      on a l'impression d'entendre d'autres "cou-clou" tremblotants, en particulier entre 34 et 39s :
      ce mâle n'est sans doute pas seul sur le lek ...
      
      Passons maintenant aux 2 turdidés plus lointains :
      
      * pas évidente si l'on ne se fie qu'au timbre ou à la hauteur du chant, mais ses répétitions sont tellement typiques :
        une **grive musicienne** fait nettement entendre un beau "tu-du-du tu-du-du" swingué à 29.8-31.1s, 
        à la fois plus dynamique, plus court, plus puissant, plus articulé, moins "lié" que le "tududu..." du Verdier ;
        
      * plus présente que la musicienne, puisqu'elle occupe un bon tiers de toute la durée de l'enregistrement,
        une **grive draine** lance ses longues notes modulées, mais autour d'une hauteur bien stable, dans une bande
        de fréquence relativement étroite, assez haut perchée pour une "bête" de cette taille : c'est peut-être
        tout cela qui lui donne cette impression d'urgence et/ou de tristesse ? On l'entend bien nettement à 7.5-8.5s,
        14.3-16, 21.5-24s, 34.5-36.5s ...
        
        remarquez aussi le côté parfois un peu vibré / roulé de certaines de ses notes, assez commun, par ex. à 3.8s,
        
        et aussi 2 phrases similaires avec répétitions très nettes à 26.8-28.2s et 38.5-40s : et oui, la Draine
        peut aussi répéter, mais c'est très peu varié, voire pas du tout, souvent plus long (au moins 4 répétitions)
        et souvent en fin de phrase plus classique, comparé à la musicienne, qui veille avec acharnement
        à ne jamais enchaîner 2 fois de suite la même répétition de motif (= 1 "motif" plus ou moins complexe,
        répétés 2 à 4 fois ; par ex., le "tu-du-du" swingué à 29.8s est le "motif", et il est répété 2 fois ici),
        
        en comparaison également, un merle a généralement un chant plus calme et posé, avec des notes moins longues,
        et/ou moins liées, plus détachées ; ces notes sont également très souvent modulées, mais rarement de manière
        oscillatoire (montant et descendant plusieurs fois de la même manière autour d'une fréquence donnée) :
        le plus souvent, elles montent puis s'arrêtent, ou redescendent un peu ; ou l'inverse ; mais sans la répétition
        correspondant aux "oscillations" de la Draine ; et puis le Merle utilise une bande de fréquences plus étendue
        que la Draine : il descend bien plus bas, et monte aussi plus haut dans les beaux sifflés ;
        quand aux "fioritures" très aiguës et complexes qu'on peut entendre à faible distance, les 2 espèces les produisent
        également ... mais comme il est moins courant d'entendre une draine de près, on les connait moins :-)
        
        écoutez par ex. le merle tout au long de <a href="#Octobre.reponse.OctBerugesVienneForetPlaine">
        l'enregistrement de Béruges</a>, et comparez :-)
        
      A moindre distance, mais leurs voix ne sont pas si puissantes, 3 ou 4 pouillots (de 2 espèces) s'égosillent
      tout au long de l'enregistrement :
      
      * assez loin quand même, noyé dans le concert, mais ressortant nettement à 11-13s et 26-28s : un **pouillot véloce**
        et son petit battement gai et sautillant,
        
      * plus proches sans doute, mais pas autant tous les 3, chacun sa petite trille rapide et courte (~1s), assez douce,
        aiguë mais à des hauteurs différentes ici : des **pouillots de Bonelli** (la 2nde espèce "opposée climatique",
        la méridionale) :
          * le 1er plus aigu (et plus proche ?) à 8.0-9.2s, 16s, 22.6s, 28.5s, 34.5s : pas d'ambiguïté,
          * le 2ème assez bas (et plus éloigné ?) à 5.8-6.7s, 12.4-13.5s, 20-21s (?), 26.5-27.5s (?) ...
          * le 3ème ... à même hauteur que le précédent, il reste des trilles "non attribuées" : à 4.2-5.3s, 21.4-22.2s,
            30-31s, et surtout celle de 36.5-37.5s, vraiment métallique et dure ... est-ce bien un Bonelli ???
                  
      D'autant qu'il y a un net "tududu" de **Verdier** au tout début de l'enregistrement ... Verdier qui pourrait bien être
      l'auteur de qq unes des trilles "non attribuées" ... mystère ?
      
      Le compte est bon : 8 espèces (pour le très probable Verdier, merci à Camille et Sylvain !).
      
      Quand au tracteur au ralenti, c'est sans doute un diesel, mais qu'en dire de plus ?-)
      """))

HTML(KOctStDisdierMontagne.lecteurHtml(urlDossierSons))

# %%
KOctBerugesForet = quizz.DescripteurExercice(

  index='b',
  id='OctBerugesVienneForetPlaine',
  titre="Forêt feuillue en plaine, dans la Vienne",
  lieu="Béruges, Vienne, Poitou-Charentes", altitude=130,
  date="15 mai 2010", heure="07:00", duree="58 s",
  auteur="<a href=\"https://www.xeno-canto.org/contributor/WXEEFPSPJM\" target=\"_blank\">Jack Berteau</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-sa/3.0/\" target=\"_blank\">CC BY-NC-SA</a>",
  milieux="""Probable chênaie-charmaie, pas loin d'un parcelle à vieux arbres, et d'une autre moins agée,
             et peut-être d'une lisière aussi, à basse altitude.""",
  fichierSon="100515-0700-Poitou-ForetPlaine-JBerteau-XC156780-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
    
  etapes=dict(
      
    lancement="""
      En plat de résistance, plutôt léger (le fromage le sera moins), farandole de sylvidés sur son lit
      de flûtes "alto" et fines perles forestières, avec une pointe d'épice africaine (8 espèces).
      """,
          
    indices2="""
      Presque à portée de main, tant elle paraît proche (belle qualité d'enregistrement !), mais oui,
      qui d'autre qu'elle peut produire ce magnifique babil grave et virtuose, si rapide et pourtant si bien articulé,
      aux notes rondes et liquides, rarement grinçantes ici ...
      
      Au second plan,
      * plusieurs phrases du 3ème turdidé, celui qui n'était pas présent à Saint-Disdier dans le Dévoluy ... comparez,
      * du même gabarit, l'africain de service nous gratifie de qq belles modulations explosives, tellement caractéristiques,
        produisant un bel écho par leur puissance et leur "gravité" (ou "bassesse" ;-),
      * une cousine de la virtuose du premier plan se fait aussi entendre vers 18.7s, 28.5s et 36s,
      * un cousin plus éloigné de ces deux-là, d'une espèce déjà présente à St-Disdier, fait entendre ses petites trilles
        simples, aiguës et sêches, à intervalles réguliers,
        
      Plus loin, à l'arrière plan,
      * encore le "trop proche de certains passereaux", bien audible tout au long de l'enregistrement,
        grâce à sa voix qui porte,
      * il ne faut pas le rater, mais il est à peu près seul sur les ondes vers 44-45s et 52-53s,
        un petit passereau très communs des milieux frais, et des potagers,
      * difficile, car il semble peu motivé, et sa phrase est tronquée ou masquée par une petite trille aiguë,
        mais sont début est caractéristique ... à 24s.
      """,
          
    reponse="""
      Oui, le virtuose du premier plan, c'est bien une **fauvette des jardins** !
      
      Accompagnée à l'arrière plan, par moments, pas une cousine "**à tête noire**" dont on n'entend que des "flûtés"
      pour cause de distance (à moins qu'au moment de l'enregistrement, elle n'ait décidé de ne pas chanter
      ses débuts habituels plus "complexes" et grinçants, moins sonores ?) :
      * bien nettement à 26.4-28s, 36-38s et 56.5-58.5s,
      * partiellement masquée par la "jardin" à 30-31s et 46-47s,
      * et à 18.5-20s, je ne pense pas que ce soit une imitation, mais juste un flûté bizarrement rythmé,
        comme interrompu au début, et repris tout de suite (une perturbation du chanteur par un élément extérieur
        vite identifié comme sans danger ?) ... le rythme est étrangement similaire à un début de phrase de grimpereau
        des jardins, c'est vrai, mais c'est bien plus grave !
        
      A quelque distance aussi, mais avec un bel écho forestier, qui fonctionne bien avec ses notes graves et appuyées :
      un **merle noir**, au chant calme, posé, plus varié et globalement plus grave qu'une grive draine,
      par exemple celle de <a href="#Octobre.reponse.OctStDisdierHameauMontagne">l'enregistrement de 
      Saint-Disdier-en-Dévoluy</a> :-).
      
      Dans le même registre, quelques phrases / notes lointaines d'un **loriot d'europe**, puissantes, fortement
      et très rapidement modulées vers les graves (courtes, avec une grande ampleur entre les aigus et les graves finaux) :
      par ex. à 22.5s, 34s, 42.4s, 53.5s (et aussi à 0.4s, 12.2s ? ) ; superbes, et également bien mises en valeur par l'écho. 
      
      A noter : pour beaucoup de ces notes, tombant assez étrangement au milieu des phrases du merle, il n'y a malgré tout
      guère de doute, cette combinaison de puissance, de vitesse et d'ampleur dans la modulation descendante ...
      ne s'entendent jamais chez le merle (à ma connaissance).
      Et la fin grave de ces notes est plus grave que les notes graves habituelles des merles.
      Pour 2 notes en revanche (à 0.4s et 22.5s), qui "s'intègrent" particulièrement naturellement aux phrases du merle,
      le doute est plus grand ; la modulation est rapide aussi, le "final" plus grave que chez un merle normal, mais ...
      difficile de trancher ...
            
      Un **coucou gris** bien sûr, plutôt éloigné, mais acharné : il n'arrête pratiquement pas de "coucouter" (ou "cuculer" ?)
      sur un rythme rapide, du début à la fin de l'enregistrement.
      
      Dans un registre plus aigu, à intervalle réguliers (toutes les 5 à 8s), une petite trille courte, rapide, aiguë, sèche
      mais plutôt douce : un **pouillot de Bonelli** ; par ex. à 1.5s, 8.5s, 14s, 19.5s, ...
      
      Plus furtifs maintenant :
      
      * vers 44-45s et 52-53s, des sifflés tremblottants typiques d'un **rouge-gorge familier**
        (et probablement aussi vers 12s et 21.5s, mais c'est plus compliqué),
      
      * dans le lointain, un début de phrase de **pinson des arbres** à 23.4s (audible seulement à 23.8s) :
        d'abord un 1er "plateau" assez "sonore", puis un second plus grave, plus ténu, jusqu'à 24.8s,
        enfin masqué par le Bonelli ; on n'entend pas la fin normale de la phrase, masquée ou tronquée ;
        
        ci-dessous, d'abord l'extrait correspondant, juste amplifié, puis un autre enregistrement "de référence"
        d'une phrase très proche, bien net, pour comparer :
        
        <table>
          <tr>
            <td>
              <audio controls>
                <source src="{{dossierSons}}/100515-0700-Poitou-ForetPlaine-JBerteau-XC156780-mono-vbr2-extrait237-257-PinArb.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              Pinson des arbres lointain, à l'arrière plan (début de phrase tronqué)
            </td>
            <td>
              <a href="{{dossierSons}}/100515-0700-Poitou-ForetPlaine-JBerteau-XC156780-mono-vbr2-extrait237-257-PinArb.mp3" download>
                <img height="20" src="{{dossierAttache}}/fa-download-solid.svg" alt="Télécharger" />
              </a>
            </td>
            <td>
              par <a href="https://www.xeno-canto.org/contributor/WXEEFPSPJM" target="_blank">Jack Berteau</a>
            </td>
            <td>
              licence <a href="https://creativecommons.org/licenses/by-nc-sa/3.0/" target="_blank">CC BY-NC-SA</a>
            </td>
            <td>
              Extrait 23.7-25.7s, non modifié
            </td>
          </tr>
          <tr>
            <td>
              <audio controls>
                <source src="https://www.xeno-canto.org/476208/download" type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              Pinson des arbres (Fringilla coelebs)
            </td>
            <td>
              <a href="https://www.xeno-canto.org/476208/download" download>
                <img height="20" src="{{dossierAttache}}/fa-download-solid.svg" alt="Télécharger" />
              </a>
            </td>
            <td>
              par <a href="https://www.xeno-canto.org/contributor/WXEEFPSPJM" target="_blank">Jack Berteau</a>
            </td>
            <td>
              licence <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/" target="_blank">CC BY-NC-SA</a>
            </td>
            <td>
              <a href="https://www.xeno-canto.org/476208" target="_blank">Page du site source</a>
            </td>
          </tr>
        </table>

      Encore plus furtifs, et quasi-impossibles à identifier sans "assistance numérique" :
      
      * dans le "silence" entre 4s et 5.5s, un battement lointain et ténu, repéré par Camille et Sylvain : très probablement
        une **mésange nonnette**, mais il faut bien avouer que ce n'est qu'après filtrage, débruitage et amplification
        de cet endroit de l'enregistrement qu'on peut le dire :
      
        <table>
          <tr>
            <td>
              <audio controls>
                <source src="{{dossierSons}}/100515-0700-Poitou-ForetPlaine-JBerteau-XC156780-mono-vbr2-extrait44-54-fphb-dbrt.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              Probable mésange nonnette (chant)
            </td>
            <td>
              <a href="{{dossierSons}}/100515-0700-Poitou-ForetPlaine-JBerteau-XC156780-mono-vbr2-extrait44-54-fphb-dbrt.mp3" download>
                <img height="20" src="{{dossierAttache}}/fa-download-solid.svg" alt="Télécharger" />
              </a>
            </td>
            <td>
              par <a href="https://www.xeno-canto.org/contributor/WXEEFPSPJM" target="_blank">Jack Berteau</a>
            </td>
            <td>
              licence <a href="https://creativecommons.org/licenses/by-nc-sa/3.0/" target="_blank">CC BY-NC-SA</a>
            </td>
            <td>
              Extrait 4.4-5.4s, filtré, débruité, amplifié
            </td>
          </tr>
        </table>
  
        Pour comparer, un meilleur enregistrement, dûment identifié, qui fait entendre un chant très similaire
        (le 2nd dans mon <a href="http://jpmeuret.free.fr/chants/FormationChants2018-application-mesanges.zip" target="_blank">
         diaporama "Mésanges"</a> :-) ... attention, baissez le volume avant :
            <a href="https://www.xeno-canto.org/55184" target="_blank">xeno-canto.org/55184</a>.
            
      * de même, derrière le merle et probable loriot au tout début de l'enregistrement, un autre petit battement aigu,
        bien visible au sonagramme, très probablement une **mésange bleue** ... mais il a fallu numériquement
        "effacer" ces 2 "parasites" (!) et encore débruiter et amplifier pour pouvoir le dire :
      
        <table>
          <tr>
            <td>
              <audio controls>
                <source src="{{dossierSons}}/100515-0700-Poitou-ForetPlaine-JBerteau-XC156780-mono-vbr2-extrait00-12-fph-debrt-amp.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              Probable mésange bleue (fin de phrase de chant)
            </td>
            <td>
              <a href="{{dossierSons}}/100515-0700-Poitou-ForetPlaine-JBerteau-XC156780-mono-vbr2-extrait00-12-fph-debrt-amp.mp3" download>
                <img height="20" src="{{dossierAttache}}/fa-download-solid.svg" alt="Télécharger" />
              </a>
            </td>
            <td>
              par <a href="https://www.xeno-canto.org/contributor/WXEEFPSPJM" target="_blank">Jack Berteau</a>
            </td>
            <td>
              licence <a href="https://creativecommons.org/licenses/by-nc-sa/3.0/" target="_blank">CC BY-NC-SA</a>
            </td>
            <td>
              Extrait 0-1.25s, filtré, débruité, amplifié
            </td>
          </tr>
        </table>

        A comparer à un meilleur enregistrement (le 1er chant dans mon 
        <a href="http://jpmeuret.free.fr/chants/FormationChants2018-application-mesanges.zip" target="_blank">
        diaporama "Mésanges"</a> :-) ... attention, baissez le volume avant :
            <a href="https://www.xeno-canto.org/161531" target="_blank">xeno-canto.org/161531</a>.
            
      Finalement, le "gémissement" grave et nasillard à 49-49.5s, assez lointain ... mystère
      (tout à fait dans les cordes - vocales - d'un geai des chênes, mais ce n'est qu'une hypothèse
       faute d'autres indices pour confirmer).
      """))

HTML(KOctBerugesForet.lecteurHtml(urlDossierSons))

# %%
KOctQuincayHetraie = quizz.DescripteurExercice(

  index='c',
  id='OctQuincayVienneForetPlaine',
  titre="Forêt feuillue et mixte en plaine, dans la Vienne",
  lieu="Forêt domaniale de Vouillé-St-Hilaire, Quincay, Vienne", altitude=150,
  date="11 avril 2015", heure="08:30", duree="57 s",
  auteur="<a href=\"https://www.xeno-canto.org/contributor/WXEEFPSPJM\" target=\"_blank\">Jack Berteau</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-sa/4.0/\" target=\"_blank\">CC BY-NC-SA</a>",
  milieux="""Hêtraie-chênaie âgée, avec qq conifères au loin (à basse altitude) ?""",
  fichierSon="150411-0830-Poitou-ForetPlaine-JBerteau-extrait-126-223-XC244399-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
    
  etapes=dict(
      
    lancement="""
      Pour le fromage, un plateau bien garni : trio de pics et son cortège de passereaux forestiers,
      surmonté d'une cerise confite d'impostures de lisière (au moins 13 espèces, sans compter les contrefaçons).
      """,
          
    indices2="""
      D'abord les plus bruyants :
      * le battement aigu au début de l'enregistrement, vous le connaissez forcément ...
      * le grand tambour (par 2 fois) : est-il long ou court, hésitant ou régulier, résonnant, grave ou aigu,
        accéléré, au volume "mourant" à la fin ? Comparez avec
        <a href="http://jpmeuret.free.fr/chants/pics-2018/pics-2018.html#Comp.t" target="_blank">ces enregistrements</a> !
      * le gémissement nasillard et couinant entre 6 et 9s ... non ce n'est pas un geai, c'est aussi un pic !
      * la phrase aiguë, stéréotypée, presque stridente ici, à 14 et 17s (par ex.) : non, pas un pic cette fois,
        mais une espèce commune qui parcourt aussi les troncs et branches sans relâche, peu farouche,
      * et la phrase aiguë, rapide, puissante, compliquée (mais on y repère différentes trilles), commençant à la fin
        d'une phrase de l'espèce précédente, à 28s : elle est émise beaucoup plus près du sol,
        et pas par une grosse bête !
        
      Il manque un pic : il occupe à peine 1 dixième de seconde de tout l'enregistrement, à 13s,
      mais cela devrait vous suffire :-)
      
      Plus difficile, car à l'arrière plan, bien bruité par qq singes hurleurs et autres bruits anthropiques :
      * 3 espèces de mésange sont présentes :
          * l'une chante nettement vers 5-6s et aussi 42-435s (2 cris caractéristiques aussi à 36s, bien que trompeurs),
          * une autre chante aussi à 15.5-17s et 22-23s par ex., plus loin, mais assez isolée à ces instants,
          * une dernière enfin, encore plus loin, mais ses cris fins, délicats sont caractéristiques ;
            pour nous aider, elle les répète plusieurs fois ici, entre 27.5 et 30s.
      * et l'omniprésent ... comme dans les 2 autres enregistrements, égrène à quelque distance sa phrase
        de 2s à 13s, 20s, 29s ... etc.
      
      Quand à l'imposteur, ce n'est pas facile non plus, il ne nous aide pas beaucoup, mais tout de même
      par 2 fois, il prononce assez discrètement certes, mais nettement, ses débuts de phrases caractéristiques,
      à 41s et 52s. Et c'est une des espèces de l'un des 4 enregistrements d'août, une vengeance ici en quelque sorte.
      
      Distinguez-vous 1 ou plusieurs des espèces probablement imitées (entre 45 et 47s, et entre 52 et 54s) ?
      Pas simple, car pas si bien imitées, et surtout par des cris.
      
      Plus loin enfin, il faut monter le volume, entre 3 et 6s, une des 3 espèces de pic chante
      (un autre individu bien sûr) ... l'entendez-vous ? et laquelle ?
      
      Et bien sûr, il est loin, mais sa voix grave et son chant simple portent loin : par ici aussi,
      certains passereaux vont en suer pour pas cher ...
      """,
          
    reponse="""
      A tous seigneurs, tous honneurs ... d'abord les pics :
      
      * les 4 gémissements nasillards et couinants entre 6 et 9s : une phrase tronquée de chant d'un **pic mar**
        (dans un chant complet, elles sont plus longues et plus véhémentes ; ici, c'est un peu hésitant),
        
      * le grand tambour, puissant, long, régulier, résonnant, grave, au volume "mourant" à la fin :
        un **pic noir** (l'épeichette, qui a également un tambour long, mais pas autant, a un rythme un peu plus rapide,
        un volume sonore assez constant, sauf hésitations assez communes, et une tonalité souvent plus aiguë à cause
        de la branche utilisée de diamètre inférieur, et donc bien moins sonore : peu d'écho comparé à notre cas) ;
        comparez les deux sur
        <a href="http://jpmeuret.free.fr/chants/pics-2018/pics-2018.html#Comp.t" target="_blank">ces enregistrements</a>,
        
        et puis, au loin, tendez l'oreille (ou plutôt montez le volume, mais attention au pouillot ;-),
        un "koui koui koui ..." qui se prolonge entre 2.5 et 5.5s ... oui, un autre pic noir, qui chante cette fois ;
        peut-être en réponse à un tambour précédent de notre "percussionniste" proche,
        à moins que ce ne soit le tambour la réponse ?
        
      * le "kik" unique, ultra-court mais bien audible : un **pic épeiche** :
          * un épeichette sonne plus aigu, avec une fondamentale à ~3000Hz, alors qu'ici elle est à ~2500Hz,
          * et également moins pur, avec un côté chuinté, peut-être dû à un surcroît d'harmoniques aiguës comparé à l'épeiche ?
          * et ses cris sont moins brutaux (ici, l'attaque est très abrupte, la fin également),
          * exemple : <a href="https://www.xeno-canto.org/304815" target="_blank">xeno-canto.org/304815</a>,
          * et puis un épeiche émet couramment des cris isolés comme ici, alors qu'un épeichette très rarement.
          
      En restant sur les chanteurs "bruyants" :
      
      * le petit battement gai, sautillant, aigu qui fait dodeliner de la tête, "tit tip tip ..." entre 0.8s et 3.8s,
        (et aussi 24-26s), bien sûr, c'est un **pouillot véloce**,
        
      * la phrase aiguë, toujours la même (en gros), presque stridente ici, à 14s, 17s, 26s ... etc, : c'est ce "traîne-écorce"
        de **Grimpereau des jardins** ("ti-ti-tu-i-ti"),
        
      * et la série variée de rafales aiguës, stridentes, rapides (différentes trilles en fait), à 28s,
        juste à la fin d'une phrase du grimpereau : un "monstre" sonore, ce "traîne-fagot" de **Troglodyte mignon**
        (mignon ... mouais ... imaginez s'il avait la taille d'un pic noir ...).
       
      Plus lointain, 3 autres chanteurs :
      
      * seul (pour une fois) à 20-22s et 55-57s, l'inévitable (en forêt) **pinson des arbres** répète inlassablement
        sa phrase sonore, composée d'une série de "trilles" plates, chacune plus grave que la précédente (effet descendant),
        série conclue par une "virgule" au timbre électronique étrange ; on l'entend aussi, mais à chaque fois
        quelque peu couvert par d'autres oiseaux plus proches, à 13-15s, 29-31s, 43.5-45.5s, ...
        
      * nettement plus grave et plus simple : un **coucou gris** semble hésiter à 5.5s (1 seul "cou" ? trop loin ?),
        progresser à 9s (un "cou cou", mais un peu grêle), puis trouver ses marques (à partir de 14s), avant de disparaître
        (vers 21s, éloignement ? extinction de voix ? attaque d'un autour ? ou pire, d'un accenteur irrascible ? ;-)
        
      * nettement plus furtif (on ne l'entend qu'une fois ?), à 19s, une modulation typique de **rouge-gorge familier**
        ("suiuuuu"), à bonne distance.
        
      De plus en plus difficile (court, loin, aigu), 3 espèces de mésange sont présentes :
      
      * au moins une **mésange bleue** émet des phrases de chant typique "tsi-dé-dé-dé ..." (ou variantes), nettement
        vers 9.5-11s, 15.5-17s, 22-23s, 39.5-41s, moins clairement vers 4-5s, 9.5-10.5s ... etc ("parasites" sur la ligne ;-),
        
      * une **mésange charbonnière** égrène des doublets aigrelets à 5-6s et 37-39s (chant) ;
        et c'est peut-être elle aussi qui crie "façon" Pinson des arbres - "tuic tuic" - juste avant,
        à moins que ce ne soit un vrai pinson ?
        
      * enfin, les fines oreilles auront "senti" la présente de quelques conifères lointains (sans en deviner l'essence ?),
        grace à 3 cris fins, traînants et légèrement modulés d'une **mésange noire**, entre 27.5s et 30s.
        
      Reste la cerise sur ce gateau déjà bien garni, en fin d'enregistrement, l'imposteur, l'imitateur de service,
      un **rouge-queue à front blanc**, qui fréquente aussi volontiers les vieilles forêts feuillues pour nicher :
      * on repère d'abord ses notes typiques de début de phrases de chant : à 41s, et surtout 52s, des "si tru tru"
        ici pas très sonores, mais qui portent souvent très loin, très diagnostiques pour l'espèce
        (mais ... méfiance tout de même, certaines fauvettes à têtes noires en sont <a href="#Aout.Anecdote">friandes</a>,
         il est prudent de guetter quelque flûté diagnostique - de fauvette - avant et après ...),
      * puis, à la ré-écoute, entre 45s et 46.7s, un enchaînement très suspect fait dresser un sourcil déjà suspicieux :
        2 cris de querelle d'<a href="https://www.xeno-canto.org/74972" target="_blank">étourneau sansonnet</a>
        suivis d'un cris de vol de <a href="https://www.xeno-canto.org/471993" target="_blank">pipit des arbres</a>
        (voire <a href="https://www.xeno-canto.org/369049" target="_blank">de Godlewski</a> pour les optimistes,
         ou les bretons cocheurs qui vont à Ouessant en automne ;-) ... mais non, ça ne sonne vraiment pas pareil !) ...
      * et ce sourcil se dresse encore un peu plus lorsqu'on ré-écoute ce qui suit immédiatement le 2nd "si-tru-tru" à 52s :
        une bribe assez convaincante de chant de <a href="https://www.xeno-canto.org/438418" target="_blank">
        linotte mélodieuse</a> (suivie de quelques "simagrées" compliquées dans le même timbre,
        dont un "tsuiii" ostensiblement allongé ... ?).
      
      Pour conclure sur une note plus "mammale", quelques **singes hurleurs** également en fond sonore ;-)
      """))

HTML(KOctQuincayHetraie.lecteurHtml(urlDossierSons))

# %%
KOctEntragesTransition = quizz.DescripteurAnecdote(
  index='a',
  id='OctTransition',
  titre="A l'approche du crépuscule, des instants de basculement",
  auteur="<a href=\"http://jpmeuret.free.fr/nature.html\" target=\"_blank\">Jean-Philippe Meuret</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-sa/4.0/deed.fr\" target=\"_blank\">CC BY-NC-SA</a>",
  fichierSon="190812-2046-Entrages-ConcertVillageSoir-HirRusHirFenDectCendDectSple-puis-debut-GrilItalGSauVert-vbr0.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
  texte="""
    Et en déssert, un peu de douceur, à plumes, et à 6 pattes (mais non, ça fait pas peur :-) ...
    
    Une belle soirée de la mi-août dans les Alpes de Haute-Provence, la température redevient agréable.
    
    La place du village est petite, à l'étroit entre la petite église récemment crépie à neuf, ses 2 vieux tilleuls,
    la moderne et banale salle des fêtes, un peu défraîchie, la vieille fontaine circulaire, le mur d'un potager
    un peu délaissé, et cette maison massive et mystérieuse, tellement grande que la moitié de la population semble y loger.
    
    Des enfants jouent et crient, alors que leurs parents discutent, attablés ou assis ici et là à la lumière
    des lampadaires qui viennent de s'allumer.
    
    A quelques mètres de là, au bout du petit parking qui jouxte la place et ouvre sur les collines
    environnantes, le départ d'un chemin, les haies qui le bordent, le pré où 4 superbes
    <a href="https://www.qwant.com/?q=irish%20cob&t=images" target="_blank">Irish Cobs</a>
    sont en train de s'installer pour la nuit, debouts, calmes, presque immobiles, repoussant mollement
    les mouches et taons déjà moins actifs de quelques puissants frémissements d'échine et élégantes arabesques de queue.
    
    Au début de l'enregistrement, des insectes noctures sont déjà bien actifs avec la baisse de luminosité rapide,
    au moins 2 espèces dans les 11 premières secondes :
    * des "tslit" ou "tslilit" assez longs bi ou tri-partites (ou plus ?), légèrements liquides, pas si secs,
      nombreux (au moins 25, parfois presque superposés, de puissances variées : plusieurs individus à différentes distances ... 4, 5, 6, ?) ;
      probablement des decticelles cendrées (Pholidoptera griseoaptera), espèce bien répandue partout en France ...
      mais il faut que je vérifie encore (exemple sur <a href="http://chant-orthoptere.com/" target="_blank">cette page</a>),
    * des "trzzèt" nettement plus courts, simples, mais souvent vibrés, voire vrillés, un très proche, l'autre plus éloigné ;
      bien moins nombreux : seulement 5 à 1s, 4s, 5.7s, 8.6s et 10.4s ; très probablement 2 individus de 
      <a href="https://inpn.mnhn.fr/espece/cd_nom/65743" target="_blank">Decticelle splendide</a> (Eupholidoptera chabrieri),
      espèce localisée dans "l'extrême" sud-est de la France, à moyenne altitude, et par ailleurs photographiée la veille
      dans le secteur, à l'occasion d'un autre concert plus "fourni" (ce qui aide à conforter l'identification ;-).
    
    Pendant ce temps, à l'arrière plan, des juvéniles de 2 espèces d'hirondelles virevoltent au dessus de la place en criant :
    * les hirondelles de fenêtre avec leurs habituels cris "prt" courts, sans voyelle, mats mais pas secs :
      ex. 2 cris entre 3 et 4s, 1 plus net à 5s ...
      (et les trik ou crik courts, plus tonaux, entre 1 et 2s, sont peut-être d'elles aussi ?)
    * les hirondelles rustiques, moins locaces et moins nombreuses, avec de "faux" cris d'alarmes "plui" ou "pli" rapides,
      courts, modulés, assez mélodieux ; ex. à 9.5s, 11.2s, 12.4s ...
      
    Vers 13.5s, un autre insecte commence timidement ses douces stridulations "truuuu", avant de trouver son rythme
    et sa puissance de "croisière" vers 17s : le Grillon d'Italie (Oecanthus pellucens), emblématique de nos nuits d'été
    (partout en France, même au nord et à l'ouest, ou presque ;
     ex. sur <a href="http://chant-orthoptere.com/" target="_blank">cette page</a>).
    
    Un pas de plus vers la nuit qui approche ...
    
    Pendant ce temps, les hirondelles continuent leur ballet bruissant dans le village ...
    
    Et à 21.5s, le dernier clou est enfoncé : une grande sauterelle verte démarre brutalement sa puissante stridulation
    rythmée "tss tss tss ..." (ex. sur <a href="http://chant-orthoptere.com/" target="_blank">cette page</a>).
    
    Dans quelques minutes, il fera nuit, les hirondelles seront couchées, les "fenêtres" probablement dans un nid,
    les "rustiques" sur quelque fil ou dans quelque arbre du voisinage (pas de roselière dans le secteur).
    """)
    
HTML(KOctEntragesTransition.lecteurHtml(urlDossierSons))

# %% [markdown]
# # Quizz de décembre

# %%
KDecIntro = """
  Ca y est le solstice est passé : écoutez et observez bien, certains oiseaux commencent à s'agiter (pics ...)
  et même déjà à chanter (sittelle, grive draine, ...) !
  
  Mais en attendant que l'allongement du jour ne les réveille finalement tous, voici 4 petits concerts saupoudrés de bruants,
  pour les longues soirées d'hiver qui restent.
"""

# %%
KDecLavandeVergerHauteProvence = quizz.DescripteurExercice(

  index='a',
  id='DecLavandeVergerHauteProvence',
  titre="Champs de lavande et verger en Haute-Provence",
  lieu="Puimoisson, Alpes-de-Haute-Provence", altitude=650,
  date="17 juin 2018", heure="6h30 du matin", duree="1ère mn, sur un total de 2 mn 05 s",
  auteur="<a href=\"https://www.xeno-canto.org/contributor/SDPCHKOHRH\" target=\"_blank\">Stanislas Wroza</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-sa/4.0/\" target=\"_blank\">CC BY-NC-SA</a>",
  milieux="""Grands champs de lavande, verger et vallon boisé sec en bordure de plateau.""",
  fichierSon="180617-0630-HauteProvence-LavandeVerger-SWroza-XC422865-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
    
  etapes=dict(
      
    lancement="""
      Pour commencer, un champ de lavande en bordure de plateau ensoleillé et sec, au dessus d'un vallon boisé
      et pas loin d'un verger, un village au loin ... des oiseaux très communs en Auvergne aussi,
      sauf pour ce premier bruant ...
      
      **Attention**, le quiz ne porte que sur la **première** minute de l'enregistrement !
      
      Au moins 5 espèces d'oiseaux (et même 6 a posteriori), et un orthoptère.
      """,
          
    indices2="""
      Le "souci", avec cet enregistrement, c'est que le bruant du 1er plan est très "proche"
      (une parabole a-t-elle été utilisée pour la captation du son ? ou un micro "canon" ?) :
      au casque, si l'on hausse le volume pour pouvoir distinguer l'arrière plan, les phrases
      du bruant deviennent trop fortes, c'est dangereux pour nos si précieux tympans !
      L'écoute avec des hauts-parleurs atténue probablement cet effet.
      
      2 espèces spécialistes du chant en vol sont audibles ici, la première presque en permancence
      en arrière-plan, même sans hausser le volume, un chant doux, un peu tristounet ou mélancolique ;
      la 2nde ne s'entend que par moments, des bribes probablement apportées de loin par des "sautes"
      de vent, mais ce qui reste de ce chant est typiquement rauque, un peu dur et roulé
      (exemple entre 9.6 et 10.9s).
      
      Moins loin que cette dernière espèce, un turdidé se fait entendre par instants au second plan,
      par exemple à 3.5s, 5.3s, 16.5s.
      
      Autre espèce : un oiseau sociable (ou plusieurs) d'abord dans le lointain à 42.8s et 44.4s,
      puis plus proche / net à 57s ...
      
      Enfin, si vous pouvez forcer le volume sans vous faire mal, entre 29 et 33s, un colombidé très lointain
      découvert par Sylvain (mais attention à vos tympans).
      """,
          
    reponse="""
      Au premier plan donc (à 1.8s, 11s, 20.3s ...), un <b>bruant ortolan</b>, avec en particulier sa note finale
      typiquement bourdonnante ("buzzzz").
      
      En vol,
      * au deuxième plan, presque en permanence, les phrases lentement (très lentement ici) descendantes
        et s'accélérant à la fin, d'une <b>alouette lulu</b> ("twu-ti twu-ti ... tlu tlu tlu ..."),
      * à l'arrière plan, très (trop) loin, par moments, quelques furtives et rudes roulades d'une <b>alouette
        des champs</b> (par ex. entre 9.6 et 10.9s).
        
      A l'arrière plan aussi, mais sans doute moins éloigné, quelques phrases d'un <b>merle noir</b>,
      trop loin cependant pour qu'on en entende la totalité - seules les parties graves et puissantes nous parviennent -
      (à 3.5s, 5.3s, 16.5s, 23.2s).
      
      A 42.8s et 44.4s, puis plus proche et net à 57s, un <b>choucas des tours</b> ("khiâaah").
    
      Très loin, vers 29-33s à peine audible, une <b>tourterelle turque</b> (et sans doute vers 27-28s, comme le suggère
      le sonagramme, mais le BruOrt couvre trop l'espace sonore à ce moment).
    
      Enfin, l'orthoptère qui stridule tout le long de l'enregistrement, 2 à 3 fois par seconde,
      c'est probablement un <b>grillon bordelais</b> (<i>Eumodicogryllus bordigalensis</i>), qu'on entend aussi en Auvergne
      en été, au moins en plaine, dans certaines parcelles agricoles où la terre est nue
      (<a href="http://chant-orthoptere.com/" target="_blank">http://chant-orthoptere.com/</a>).
      
      Quand aux diptères ou hyménoptères qui passent en trombe vers 8s, 17s, 26s, 40S ... etc,
      ils resteront anonymes :-)
      """))

HTML(KDecLavandeVergerHauteProvence.lecteurHtml(urlDossierSons))

# %%
KDecGrandesCulturesAngleterre = quizz.DescripteurExercice(

  index='b',
  id='DecGrandesCulturesAngleterre',
  titre="Plaine agricole, au nord de l'Angleterre",
  lieu="Helperthorpe, District de Ryedale, Yorkshire du Nord, Angleterre", altitude=80,
  date="3 juillet 2011", heure="avant 5h du matin", duree="1 mn 20 s",
  auteur="<a href=\"https://www.xeno-canto.org/contributor/BTOFEKXFGW/\" target=\"_blank\">David M.</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-nd/4.0/\" target=\"_blank\">CC BY-NC-ND</a>",
  milieux="""Haies et grandes cultures, à quelque distance d'un bois ou d'un parc arboré.""",
  fichierSon="110703-0447-NorthYorkshire-GrandesCultures-DavidM-XC205618-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
    
  etapes=dict(
      
    lancement="""
      Ensuite, un petit concert de grands espaces agricoles en climat assez frais, Angleterre oblige,
      dans le <a href="https://fr.wikipedia.org/wiki/Yorkshire_du_Nord" target="_blank">Yorkshire du Nord</a>
      (<a href="https://en.wikipedia.org/wiki/North_Yorkshire" target="_blank">North Yorkshire</a>),
      qui ressemble un peu à certains endroit de la limagne des confins du Puy-de-Dôme et de l'Allier,
      si l'on en juge par ces <a href="https://www.geograph.org.uk/search.php?i=107275377&page=1&displayclass=thumbs"
                                 target="_blank">quelques photos</a>.

      6 espèces au moins (et même 8 a posteriori), dont 2 autres bruants ...
      """,
          
    indices2="""
      D'abord, au premier plan ou pas très loin, nos 2 nouveaux bruants, qui semblent s'écouter l'un l'autre,
      en alternance, au début au moins (plus vraiment à 1mn04s) :
      * l'un à 2s, 12s, 20.5s, 30s,
      * l'autre à às, 8s, 18s, 24s, 32s.
      
      Toujours assez proche, un beau fringille des espaces ouverts, plutôt discret en général, commun mais
      peu dense chez nous ; ici, pendant presque tout l'enregistrement, et en particulier dans les 15 premières
      secondes, on entend 2 individus au moins qui babillent ou crient doucement presque en continu,
      d'une voix peu puissante mais par des phrases complexes et rapides.
      
      Plus éloignées, 3 "volailles" pour les chasseurs, par ordre de taille décroissante :
      * une qui ne vole pas très bien, mâle bariolé, femelle plus mimétique : à 15s, 19s, 39.4s (loin),
        et surtout 57.5s (bien plus proche : un 2nd mâle),
      * une qui vole très bien : comme un fond permanent de chant (assez grave) dans le lointain,
        avec des accents plus nets typiques à 12-14s au moins,
      * une dernière qui vole bien, mais ne le montre guère : très difficile ici, car éloignée
        et sonnant de ce fait comme certaines parties des phrases des linottes ; le rythme des phrases est cependant
        absolument diagnostique : à 38.5, 39.5, 40.4s, 1mn07.2s, 1mn08.1s, 1mn09s au moins
        (mais il faut pousser le volume autant que possible ... encore une découverte de Sylvain :-).
        
      Bien audible, un corvidé à 15s (mais vous ne l'aurez pas raté celui-ci :-).
      
      Enfin, plus difficile, comme en Haute-Provence, une espèce dont des bribes de chant rauques et roulées sont apportées
      de loin par des "sautes" de vent, assez nettes vers 15-16s.
      """,
          
    reponse="""
      Les 2 <b>bruants</b> polis sont donc :
      
      * le <b>Jaune</b>, à 2s, 12s, 20.5s, 30s, ... un individus facécieux qui produit en une minute
        plusieurs type de phrases (voir sonagrammes ci-dessous) :
          1. la 2ème phrase (à 12s) est du type "habituel" (pour nous auvergnats), à 2 types de notes,
             la 1ère courte et répétée en montant légèrement, sur un rythme assez lent, formant l'essentiel de la phrase,
             la 2nde plus longue et traînante, terminale, modulée descendante, plus grave (type de phrase "XsB" de Hansen),
          2. dans la 3ème et la 7ème phrase (à 20.5s et 1mn04s), cette dernière note a simplement disparu,
             il ne reste que la "trille" qui n'est pas montante ici d'ailleurs, et plus grave que dans la 2nde phrase,
          3. la 1ère, la 5ème et la 6ème phrase (à 2s, 44s et 54s) dont légèrement différentes :
             l'oiseau ajoute au contraire une note supplémentaire finale très aiguë et stridante / bourdonnante à la fin,
             fortement modulée vers le bas (type de phrase "BC" de Hansen),
          4. enfin, dans la 4ème et la 8ème phrase (à 30s et 1mn13s), toujours par rapport au "modèle" que l'on connait,
             celui de la 2nde phrase, l'oiseau introduit une plus courte et très aiguë entre la trille et la finale
             plus grave et longue (type de phrase "XlB" de Hansen) ; comme pour la 3ème et la 7ème phrase, la trille initiale
             est plus grave que dans le "modèle" de la 2ème phrase, à la même hauteur que la finale,
          5. car oui, même les bruants jaunes ont un répertoire (plus ou moins) varié, et cet individu est probablement
             assez original par son inconstance ; d'ailleurs, il existe un ensemble de dialectes différents en Europe
             et dans le monde entier, <a href="http://jpmeuret.free.fr/chants/bruants-2020/bruants-2020.html#BruantJaune.ch"
             target="_blank">dialectes qui ont été étudiés et répertoriés en détails, et même partiellement cartographiés</a>.
             
      * le <b>Proyer</b>, à 0s (fin de phrase), 8s, 18s, 24s, 32s, ... à quelque distance, avec sa phrase sur-aiguë,
        qui débute par une courte trille s'accélèrant rapidement, et se termine par une mélodie complexe et ultra-rapide
        ressemblant à un montage infernal de multiples vieilles poulies rouillées et grinçantes.
      
      <table>
        <tr>
          <td>
            <img src="{{dossierAttache}}/110703-0447-NorthYorkshire-GrandesCultures-DavidM-XC205618-BruJau-extraits.jpg"/>
            <p>Bruant jaune : Les 4 types de phrases de l'enregistrement (numérotation dans l'ordre du paragraphe ci-dessus)</p>
          </td>
        </tr>
      </table>
      
      Moins polies, car chantant de-ci de-là tout au long de l'enregistrement, au moins 2 <b>linottes mélodieuses</b> babillent
      délicatement et avec constance et variété entre 0 et 15s. A faible distance.
   
      Quand aux 3 "volailles de chasse" :
      * des <b>pigeons ramiers</b> (très probablement plusieurs) chantent en "permanence" au loin,
        avec des accents plus nets à 12-14s au moins,
      * un <b>faisan de Colchide</b>
        <a href="https://archive.org/stream/GlossairePatoisDuDpartementDille-et-vilaine/glossaire_patois_ille_vilaine_djvu.txt" target="_blank">
        s'écocaille</a> (ou s'écoquaille plutôt ?) vers 15s, 19s, 39.4s (loin), et surtout 57.5s (bien plus proche) ;
        un volatile très anciennement exotique semble-t-il,
        puisqu'<a href="https://www.thefield.co.uk/shooting/the-history-of-the-pheasant-22364" target="_blank">
        il pourrait avoir été importé dans les Iles Britanniques dès le XIème siècle (?)</a>,
      * une <b>caille des blés</b> (très loin) paye ses dettes avec une furieuse et honnête volonté à 38.5, 39.5, 40.4s,
        et à 1mn07.2, 1mn08.1, 1mn09s au moins (très difficile à séparer du reste : même son que certaines parties
        des chants de linottes ... mais rythme swingué ultra-spécifique "pèt pè-pèt" !!!),      

      Le corvidé de corvée est bien une <b>corneille noire</b>, vers 35-38s, avec son beau ramage plein d'harmoniques
      (c'est un fait ... pas qu'il soit beau, mais plein d'harmoniques ; certain renard en peut témoigner :-).
      
      Enfin, très loin, comme dans l'enregistrement de Haute-Provence, une <b>alouette des champs</b> nous envoie
      quelques bribes par moments, assez audibles entre 15 et 18s (et surtout 15-15.7s, la trille rauque
      qui résiste le mieux à la distance).
      """))

HTML(KDecGrandesCulturesAngleterre.lecteurHtml(urlDossierSons))

# %%
KDecCollineCalcaireBourgogne = quizz.DescripteurExercice(

  index='c',
  id='DecCollineCalcaireBourgogne',
  titre="Colline calcaire en Bourgogne",
  lieu="Montagne de la Chaume, Nantoux, Bourgogne", altitude=440,
  date="28 mars 2005", heure="7h du matin", duree="1 mn",
  auteur="<a href=\"https://www.xeno-canto.org/contributor/QOTYTAAQAK\" target=\"_blank\">Gérard Olivier</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-sa/3.0/\" target=\"_blank\">CC BY-NC-SA</a>",
  milieux="""Anciens parcours pastoraux en voie de fermeture, sur colline calcaire aux pentes boisées.""",
  fichierSon="050328-0700-Bourgogne-CollineCalcaire-GOlivier-XC143131-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
    
  etapes=dict(
      
    lancement="""
      Ensuite, une ambiance typique de début de printemps, avec les habituels chanteurs précoces
      (attention à une furtive et possible imitation ...), accompagnés par un mélodieux migrateur ...
      et par un autre bruant.
      
      8 espèces au moins (en fait 10 a posteriori, et puis finalement seulement 9), dont un 4ème et dernier bruant.
      """,
          
    indices2="""
      Au premier plan, trop fort à mon goût (à vous vriller les cils de la cochlée), ces phrases rapides,
      aiguës, un peu aigres ... un "traine-buisson" prudent qui se laisse parfois aller à moins de discrétion
      au printemps, lorsqu'il chante bien en vue du haut d'un arbuste
      (même problème qu'avec le 1er enregistrement, où le chanteur du premier plan empèche de hausser suffisamment
       le volume pour tout entendre de l'arrière plan ...).
      
      Bien audibles sans pousser le volume cependant, au deuxième plan :
      * le mélodieux migrateur à 8.5-11s, 17-19s, ...
      * un turdidé pédagogue à 5-5.5s, 11-13s, ... mais un peu farceur quand même à 49.5-52s,
      * le bruant à 2.7-4.2s à 35.5-37s
      * des miaulements en début d'enregistrement ... imitateur ou imité (j'hésite) ?
      
      Egalement bien audible, dans les graves, bien que plus éloigné, un oiseau très commun jusque dans nos villes,
      entre 41 et 53s.
      
      Plus furtifs :
      * repérez-vous le chant alterné typique vers 29.5-32s (et ailleurs aussi) ?
      * je suis sûr que vous avez détecté les "touiou" très courts, très modulés,
        à 2s, 7-8.5s, 21.5s, 27.5s, 34.8s, 39.5, 40.5, ... c'est tout ce qui reste du chant plus complexe
        d'un ... oui, d'un limicole : il doit y avoir un marais ou un fond humide bien dégagé
        en contrebas à bonne distance ...
      * un unique "tu-tluî" doux bien audible à 43.6-43.9s dénonce sans ambiguïté l'espèce passant en vol.
        
      Enfin, dernier effort en forçant le volume (attention à l'accenteur !), 2 espèces découvertes par Sylvain (!) :
      * des cris de vol assez typique aussi à 54.5-55.5s,
      * au loin, une mésange à 24.8-25.5s (cris répétés ou bribe de chant ?), mais laquelle ?
      """,
          
    reponse="""
      Le discret traîne-buisson qui occupe avec autorité le premier plan, c'est bien un <b>accenteur mouchet</b> !
      
      Au deuxième plan :
      * le mélodieux migrateur est un <a href="https://www.xeno-canto.org/298818" target="_blank">pouillot fitis</a> :
        lorsqu'il retourne dans ses quartiers de nidification en Europe du nord et centrale, en partant
        de son hivernage africain, il chante abondamment en chemin, et il ne faut pas croire sérieusement
        à son installation partout où il se fait entendre, sauf si le chant se prolonge tard en mai dans les lieux frais
        et humides réellement favorables !
      * le turdidé pédagogue, vous l'avez reconnu par ses répétitions : une <b>grive musicienne</b> ; 
        à 49.5-52s, elle répète un motif qui ressemble à un chant de Sittelle, mais est-ce pour autant une imitation ?
      * le <b>bruant</b> de service est ici un <b>zizi</b>, au second plan, avec sa trille "plate" (la même note répétée rapidement
        sans variation), pas trop sèche ici, presque mélodieuse,
      * et les miaulements du début sont émis par une <b>buse variable</b> ... à moins qu'il ne s'agisse d'un <b>geai
        des chênes</b> (le "cri de buse" est de loin l'imitation préférée du "roi des glandeurs" ;-)

      Plus furtifs :
      * le chant alterné "ti-tiu ti-tiu ti-tiu ..." décidé, puissant, un peu strident à l'arrière plan, c'est celui
        d'une <b>mésange charbonnière</b> bien sûr !
      * et l'unique "tu-tluî" doux à 43.6-43.9s, c'est très probablement un cri de vol d'<b>Alouette lulu</b>,
      * enfin, et j'en suis tout étonné, mais plus aucune trace du limicole qui "touïoute" à tire d'ailes au loin,
        et que j'avais identifié avec certitude comme un <a href="https://www.xeno-canto.org/501887" target="_blank">
        vanneau huppé</a> lors de multiples écoutes ! En fait, l'analyse visuelle du sonagramme révèle que :
          * TOUS les instants où j'ai crû entendre le vanneau correspondent à un motif similaire de l'accenteur
            (qui dessine des modulations brutales et répétées vaguement cohérentes avec celles, typiques, du Vanneau huppé,
             vers 0.2-0.3s et 0.5s sur le sonagramme de gauche ci-dessous),
          * à chaque fois au même moment dans sa phrase (à la fin),
          * mais sans aucune trace des multiples harmoniques qu'on devrait voir si c'était bien un vanneau
            (sonagramme de droite ci-dessous).
        
        <table>
          <tr>
            <td>
              <a href="{{dossierSons}}/050328-0700-Bourgogne-CollineCalcaire-GOlivier-XC143131-extrait-vanhup.mp3"
                 download>
                <img src="{{dossierAttache}}/AccenteurMouchet-ch-extrait-79-85ds-XC143131.jpg"
                     class="shrinkable" alt="Télécharger" />
              </a>
              <p>Accenteur mouchet, 28/03/2005 (extrait 7.9-8.5s)</p>
              <p>Montagne de la Chaume, Nantoux, Bourgogne, France</p>
              <audio controls class="audio-player">
                <source src="{{dossierSons}}/050328-0700-Bourgogne-CollineCalcaire-GOlivier-XC143131-extrait-vanhup.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
              <p style="margin: 0 0 0 0">
                par <a href="https://www.xeno-canto.org/contributor/QOTYTAAQAK" target="_blank">Gérard Olivier</a>,
                licence <a href="https://creativecommons.org/licenses/by-nc-sa/3.0/" target="_blank">CC BY-NC-SA</a>
              </p>
              <p style="margin: 5px 0 0 0">
                Enregistrement source <a href="https://www.xeno-canto.org/143131" target="_blank">XC143131</a>
              </p>
            </td>
            <td>
              <a href="{{dossierSons}}/180426-2234-VanneauHuppe-OSwift-XC501887-extrait.mp3" download>
                <img src="{{dossierAttache}}/VanneauHuppe-ch-extrait-27-35ds-XC501887.jpg"
                     class="shrinkable" alt="Télécharger" />
              </a>
              <p>Vanneau huppé, 26/04/2018 (extrait 2.7-3.5s)</p>
              <p>Le Plessis-Lastelle, Manche, Normandie, France</p>
              <audio controls class="audio-player">
                <source src="{{dossierSons}}/180426-2234-VanneauHuppe-OSwift-XC501887-extrait.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
              <p style="margin: 0 0 0 0">
                par <a href="https://www.xeno-canto.org/contributor/JCPKCBKKAQ" target="_blank">Olivier Swift</a>,
                licence <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/" target="_blank">CC BY-NC-SA</a>
              </p>
              <p style="margin: 5px 0 0 0">
                Enregistrement source <a href="https://www.xeno-canto.org/501887" target="_blank">XC501887</a>
              </p>
            </td>
          </tr>
        </table>
        
        Surprenante illusion sonore, qui perdure longtemps, puis disparaît un jour complètement =8-) ...
        Se serait-elle produite sur le terrain, en direct ? A méditer ...
      """))

HTML(KDecCollineCalcaireBourgogne.lecteurHtml(urlDossierSons))

# %%
KDecBocageBassesCombrailles = quizz.DescripteurExercice(

  index='d',
  id='DecBocageBassesCombrailles',
  titre="Bocage et bois en Basses Combrailles",
  lieu="Les Pauses, Champs, Puy-de-Dôme", altitude=540,
  date="26 mai 2019", heure="8h du matin", duree="1 mn",
  auteur="<a href=\"http://jpmeuret.free.fr/nature.html\" target=\"_blank\">Jean-Philippe Meuret</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-sa/4.0/deed.fr\" target=\"_blank\">CC BY-NC-SA</a>",
  milieux="""Prairies, haies, bois et lande sur pente exposée au nord.""",
  fichierSon="190526-0803-ChampsLesPausesN-Concert-JPM-mono-vbr2.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
    
  etapes=dict(
      
    lancement="""
      Et pour terminer, un chorus matinal de bocage "bien de chez nous", assez dense,
      avec des fauvettes, des bruants (déjà entendus dans les 3 précédents concerts) ...
      mais pas de scoubidous <:-O.
      
      Au moins 12 espèces (ah non, finalement 11) ...
      dans un enregistrement d'assez médiocre qualité, pour simplifier l'analyse :-)
      """,
          
    indices2="""
      Place d'abord aux fauvettes, avec 2 espèces bien audibles, la 3ème beaucoup plus difficilement :
      * 3 phrases assez nettes et isolées (surtout la 2ème) à 2-3.5s, 6.7-7.5s et 6.8-8.3s : 1ère espèce,
      * 1 phrase assez isolée, plus courte que généralement, mais au timbre typique à 12-15s : 2ème espèce,
      * c'est presque subliminal tant le concert est dense à cet instant, mais une petite mélodie familière
        semble surnager entre 39.5 et 40.5s : 3ème espèce (avec un petit doute quand même).
        
      Ensuite, les bruants ; en fait, une seule espèce chante, l'autre crie :
      * le chanteur, ou peut-être les 2 chanteurs - car 2 phrases différentes semblent alterner -
        se signalent par exemple à 5s, 14s, 18s, 22s, 27s, 32s, ...
      * le "tsi" lancinant, répété durant TOUT l'enregistrement toutes les 1 à 3 secondes ... c'est le cri
        d'inquiétude assez typique de la seconde espèce (et c'était un point d'écoute STOC EPS,
        l'inquiétude a duré au moins 5mn ;-)
        
      Ensuite des espèces encore assez repérables :
      * entendez-vous la petite répétition gaie et rythmée (dans les aigus) par exemple à 4-6s, 11-13.5s, 19-21s ... ?
      * et la longue note modulée, triste, à 2.5-3.5s ?
      * et les belles modulations graves vers 47-49s (aussi 41-42.6s et 55.5-57.5s) ?
      
      Plus difficile, plus noyés dans le chorus :
      * repérez-vous les "thiuu" longs aspirés vers 13s et 21s, et les "plouit" courts en rafale vers 23s ?
      * et à 14.5s, dans les graves rauques (au loin) ?
      * et les séries répétées sifflées aiguës descendantes qui surnagent seules vers 1.5-2.5s, 25-26s,
        45.5-46.5s et 52-53s au moins ?
        (difficile ici, on a juste une partie des phrases habituelles consituées de répétitions descendantes)      
      """,
          
    reponse="""
      Les 3 fauvettes, dans l'ordre des indices de la mi-parcours :
      1. <b>Fauvette des jardins</b> : quelques notes graves, liquides (un ruisseau qui coule),
         débit virtuose, phrases rapides mais bien articulées,
      2. <b>Fauvette grisette</b> : phrases courtes, assénées, un peu grinçantes, moins claires et plus précipitées,
      3. <b>Fauvette à tête noire</b> : difficile ici, avec juste une lointaine bribe de flûté surnageant
         au dessus du concert dense.
      
      Côté <b>bruants</b>,
      * le chanteur est un <b>jaune</b> (2 individus présents ?),
      * le "crieur" est un <b>zizi</b>, il n'arrête pas ses "tsi" de protestation (mea culpa) ...
      
      Côté encore accessible :
      * un <b>pouillot véloce</b> "sautille" gaiement (vers 4-6s par ex.),
      * une <b>grive draine</b> module plus tristement (vers 2.5-3.5s),
      * un <b>Merle noir</b> module avec plus d'optimisme, plus "gravement" et calmement (vers 47-49s par ex.).
      
      Côté ... difficile :
      * un <b>rossignol philomèle</b> perce par moment l'air épais du chorus matinal
        (longs "thiuu", rafales de "plouit" courts),
      * une <b>corneille noire</b> croasse au loin (vers 14.5s),
      * un <b>pinson des arbres</b> égrène ses phrases descendantes "par plateaux",
        mais il ne nous en parvient que des morceaux (par ex. entre 1s et 3s).
      """))

HTML(KDecBocageBassesCombrailles.lecteurHtml(urlDossierSons))

# %%
KDecImposteurMasque = quizz.DescripteurAnecdote(
  index='a',
  id='DecImposteurMasque',
  titre="L'imposteur portait un masque",
  auteur="<a href=\"http://jpmeuret.free.fr/nature.html\" target=\"_blank\">Jean-Philippe Meuret</a>",
  licence="<a href=\"https://creativecommons.org/licenses/by-nc-sa/4.0/deed.fr\" target=\"_blank\">CC BY-NC-SA</a>",
  fichierSon="190602-0815-LudessePratBlancN-ImposteurMasque.mp3",
  dossierSons=urlDossierSons, dossierAttache=urlDossierAnnexes,
  texte="""
    C'est sans doute pour cela qu'après plusieurs minutes d'allées et venues erratiques à quelques distance,
    ponctuées de cris d'alarme (ou plutôt d'agacement), il s'est finalement résolu à (probablement re-)venir
    chanter à son poste habituel, une aubépine suffisamment agée pour me dépasser, mais pas assez pour me cacher ;
    car c'est tout contre elle, au bord du chemin taillé à même le granit-mère, à quelques cm de ses épines acérées
    et sous son ombrage plus que léger, que j'avais décidé de passer les 10 prochaines minutes de ma vie d'espion,
    avec le doublement infâme projet d'enregistrer la scène et de noter scrupleusement l'identité,
    le nombre et l'éloignement estimé de tous les volatiles qui commettraient l'erreur de se laisser aller
    à quelque manifestation trop sonore ou trop visible ; tâche ô combien ingrate et harrassante, vous l'imaginez,
    sous un ciel si bleu et dans une si belle campagne encore exempte de bruits humains en cette heure matinale
    d'un dimanche de juin ...
    
    Mais je m'égare ...
    
    Posé de l'autre côté de l'aubépine, à moins de 3 mètres ... après encore quelques cris rageurs pour la forme ...
    il a donc repris son poste et son activité de chant ; et il a bien fait de rester masqué, car c'est un faussaire,
    un imposteur, d'un genre discret car son chant ne porte guère, mais d'une trempe brillante et méticuleuse !
    Tellement que par moments, avec une grande virtuosité, il semble suivre une partition ouverte sous ses yeux,
    une partition d'un genre spécial : une page d'un chapitre d'une encyclopédie qui répertorierait les plus menus détails
    de chaque forme et variante de cri et de chant de chaque espèce d'oiseau connue
    (si seulement je pouvais trouver l'endroit où il la cache ...).
    
    Est-ce que vous reconnaissez les 4 espèces communes qu'il imite ici plus que clairement 
    (pour la dernière, la partition paraît très érudite, mais pour la deuxième, il reste du travail :-) ?
    
    Cherchez d'abord, avec les indices (forcément) codés suivants :
    1. 3-8s et 86.3-94,
    2. 37.5-40,
    3. 53-63,
    4. 66-86.
    
    <a href="javascript:show('dDecImpostMasq.imit')" id="dDecImpostMasq.imits">
      <img height="32" src="{{dossierAttache}}/fa-eye-regular.svg" alt="Montrer" />
      cliquez pour découvrir la suite (MAIS ... uniquement si vous avez bien cherché !)
    </a>
    
    <div id="dDecImpostMasq.imit" style="display: none">
    
      <a href="javascript:hide('dDecImpostMasq.imit')">
        <img height="32" src="{{dossierAttache}}/fa-eye-slash-regular.svg" alt="Cacher" />
        cliquez pour masquer la suite ;-)
      </a>

      <p>Espèces imitées : à chaque fois, cris / chants concernés, où trouver l'imitation dans l'enregistrement,
                           exemples d'enregistrements de l'espèce imitée, et enfin extrait contenant l'imitation
                           par notre faussaire masqué :</p>

      <table>
        <thead>
          <tr>
            <th>Espèce imitée</th>
            <th>Type de cri / chant</th>
            <th>Moment de l'extrait</th>
            <th>Versions originales</th>
            <th>Imitation</th>
          </tr>
        <thead>
        <tbody>
          <tr>
            <th><b>Merle noir</th>
            <td>cris d'inquiétude "cok cok", "pix pix" puis fuite</td>
            <td>2.5-8.5s</td>
            <td>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/385911/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/312424/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/298600/download" type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              <audio controls class="audio-player">
                <source src="{{dossierSons}}/190602-0815-LudessePratBlancN-ImposteurMasque-extr-MerNoi-cr-inq-fuit.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
            </td>
          </tr>
          <tr>
            <th>Rossignol philomèle</th>
            <td>2-3 motifs courants de chant</td>
            <td>37.5-40s</td>
            <td>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/475972/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/474821/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/459855/download" type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              <audio controls class="audio-player">
                <source src="{{dossierSons}}/190602-0815-LudessePratBlancN-ImposteurMasque-extr-RosPhi-ch.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
            </td>
          </tr>
          <tr>
            <th>Etourneau sansonnet</th>
            <td>Cris de querelles entre individus</td>
            <td>53-55.5s</td>
            <td>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/25864/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/74972/download" type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              <audio controls class="audio-player">
                <source src="{{dossierSons}}/190602-0815-LudessePratBlancN-ImposteurMasque-extr-EtoSan-cr-disput.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
            </td>
          </tr>
          <tr>
            <th>Etourneau sansonnet</th>
            <td>Chant spécifique et imitatif (cris de moineau domestique)</td>
            <td>1mn01s-1mn03s</td>
            <td>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/408221/download" type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              <audio controls class="audio-player">
                <source src="{{dossierSons}}/190602-0815-LudessePratBlancN-ImposteurMasque-extr-EtoSan-ch-spec-et-imit-bof.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
            </td>
          </tr>
          <tr>
            <th>Moineau domestique</th>
            <td>Florilège de divers cris sociaux excités</td>
            <td>1mn06s-1mn26s</td>
            <td>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/173498/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/170194/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/436230/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/239375/download" type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              <audio controls class="audio-player">
                <source src="{{dossierSons}}/190602-0815-LudessePratBlancN-ImposteurMasque-extr-MoiDom-cr.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
            </td>
          </tr>
          <tr>
            <th>Merle noir</th>
            <td>Chant calme, avec notes roulées et fioritures finales</td>
            <td>1mn26.3-1mn33s</td>
            <td>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/487551/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/481575/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/499806/download" type="audio/mpeg" preload="none"/>
              </audio>
              <audio controls class="audio-player">
                <source src="https://www.xeno-canto.org/516340/download" type="audio/mpeg" preload="none"/>
              </audio>
            </td>
            <td>
              <audio controls class="audio-player">
                <source src="{{dossierSons}}/190602-0815-LudessePratBlancN-ImposteurMasque-extr-MerNoi-ch.mp3"
                        type="audio/mpeg" preload="none"/>
              </audio>
            </td>
          </tr>
        <tbody>
      </table>
      
    </div>
            
    Et si le coeur (bien accroché ?) vous en dit, un autre exercice intéressant : forcez-vous à ignorer l'imposteur
    (pas simple, il est très bavard et occupe presque toute la durée de l'enregistrement) et décortiquez le fond sonore
    en "écoutant à travers le mur du premier plan sonore" ; vous y trouverez encore au moins 6 espèces d'oiseaux,
    des "vraies" ... et une espèce de grillon.
    
    <a href="javascript:show('dDecImpostMasq.fond')" id="dDecImpostMasq.fonds">
      <img height="32" src="{{dossierAttache}}/fa-eye-regular.svg" alt="Montrer" />
      cliquez pour découvrir la suite (MAIS ... uniquement si vous avez bien cherché !)
    </a>
    
    <div id="dDecImpostMasq.fond" style="display: none">
    
      <a href="javascript:hide('dDecImpostMasq.fond')">
        <img height="32" src="{{dossierAttache}}/fa-eye-slash-regular.svg" alt="Cacher" />
        cliquez pour masquer la suite
      </a>
      
      <p>Derrière l'imposteur et son masque, à l'arrière plan :</p>
      <ul>
        <li>Alouette lulu : par ex. à 1-2s,9-10s, 1mn05s, 1mn08.5s,</li>
        <li>Fauvette à tête noire : par ex. à 4s, 19s,</li>
        <li>Pinson des arbres : par ex. à 5.5s, 15-16s, 1mn,</li> 
        <li>Merle noir : par ex. à 25-26s (?), 58.5s, 1mn24-25s,</li>
        <li>Fauvette grisette : par ex. à 31s (assez loin),</li>
        <li>Alouette des champs : loin, des bribes roulées, rauques vers 1:08s, 1:15-1:17s,</li>
        <li>... et beaucoup de grillons des champs (<i>Grillus campestris</i>), sans arrêt.</li>
      </ul>
      
    </div>""")
    
HTML(KDecImposteurMasque.lecteurHtml(urlDossierSons))

# %% [markdown]
# # Génération de la page

# %%
KQuizz = \
[quizz.DescripteurQuizz(id='Aout', titre='Quizz d\'août',
                        intro=KAoutIntro,
                        publier=dict(lancement=True, indices2=True, reponse=True),
                        exercices=[KAoutStGenesChampEstive, KAoutClairiereBassesCombrailles, KAoutMaquisForetOccitannie],
                        anecdotes=[KAoutImitations],
                        effort=dict(infrastructure=2, lancement=11, indices2=6, reponse=7, anecdotes=3, courrier=11)),
 quizz.DescripteurQuizz(id='Octobre', titre='Quizz d\'octobre',
                        intro=KOctIntro,
                        publier=dict(lancement=True, indices2=True, reponse=True),
                        exercices=[KOctStDisdierMontagne, KOctBerugesForet, KOctQuincayHetraie],
                        anecdotes=[KOctEntragesTransition],
                        effort=dict(infrastructure=2, lancement=5, indices2=3, reponse=8, anecdotes=3, courrier=7)),
 quizz.DescripteurQuizz(id='Decembre', titre='Quizz de décembre',
                        intro=KDecIntro,
                        publier=dict(lancement=True, indices2=True, reponse=True),
                        exercices=[KDecLavandeVergerHauteProvence, KDecGrandesCulturesAngleterre, 
                                   KDecCollineCalcaireBourgogne, KDecBocageBassesCombrailles],
                        anecdotes=[KDecImposteurMasque],
                        effort=dict(infrastructure=2, lancement=11, indices2=4, reponse=10, anecdotes=4, courrier=7)),
]

nomFicCible = \
    quizz.buildHtmlPage(titre="Les Oiseaux à l'Oreille : Quizzzzz 2019",
                        sousTitre="C'est la reprise, fini les vacances : à vos oreilles, prêt(e)s, écoutez !",
                        description="Quizz 2019 d'application de la formation \"Les Oiseaux à l'Oreille\"",
                        motsClef='auvergne, forêt, bocage, maquis, estive, montagne, plaine, agricole, marais' \
                                 'bruant, rougequeue, fauvette, alouette, pouillot, pipit',
                        preambule=KPreambule, quizz=KQuizz, etapes=KEtapes, attribsEtMercis=KAttribsEtMercis,
                        dossierAttache=urlDossierAnnexes, dossierSons=urlDossierSons,
                        images=dict(imgTMat=[dict(img='RouFBl-JCLablanquie-20190421.jpg',
                                                  legend='Rouge-queue à front blanc, mâle'),
                                             dict(img='BruJau-f-RRiols-20160620.jpg',
                                                  legend='Bruant jaune, femelle')]),
                        notebook='Quizz2019.ipynb', prefixeFicCible='quizz-2019',
                        effort=sum(sum(q.effort.values()) for q in KQuizz))

HTML("""<p>Quizz 2019 <a href='{nomFic}' target="_blank">{nomFic}</a> (nouvel onglet)</p>""".format(nomFic=nomFicCible))

# %%
raise Exception("On s'arrête ici !")

# %%
implib.reload(module=quizz)

# %%
HTML(quizz.infosEnregXC(nr=471826))
